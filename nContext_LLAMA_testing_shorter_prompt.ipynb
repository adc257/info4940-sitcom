# %% [markdown]
# <a href="https://colab.research.google.com/github/adc257/info4940-sitcom/blob/main/nContext_LLAMA_testing_shorter_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.29.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
from google.colab import userdata
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
import torch
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from copy import deepcopy
import random
import json
import math
import os

# %%
# !git clone https://github.com/adc257/info4940-sitcom.git

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'info4940-sitcom'...
# remote: Enumerating objects: 1122, done.
# remote: Counting objects: 100% (1122/1122), done.
# remote: Compressing objects: 100% (202/202), done.
# remote: Total 1122 (delta 972), reused 1046 (delta 917), pack-reused 0
# Receiving objects: 100% (1122/1122), 14.75 MiB | 20.24 MiB/s, done.
# Resolving deltas: 100% (972/972), done.
# Mounted at /content/drive

# %% [markdown]
# # Defining some helper functions

# %%
def list_files(start_path):
    file_paths = []
    for root, dirs, files in os.walk(start_path):
        for file in files:
            file_paths.append(os.path.join(root, file))

    file_paths.sort()
    return file_paths

def fPathList_TO_DialogueWithContext(filePathList, nSentenceContext):
  humorous_inputs = []
  non_humorous_inputs = []

  # formatted_inputs = []
  # labels = []

  for episodePath in filePathList:

    with open(episodePath, 'r') as file:
      data = json.load(file)
      data = [info for (_, info) in data.items()]


      i = nSentenceContext
      while i < len(data):
        context = [data[j] for j in range(i-nSentenceContext, i)]
        target = data[i]

        if 'isHumor' in target:
          humorous_inputs.append(transformInput(context, target))
        else:
          non_humorous_inputs.append(transformInput(context, target))

        i += 1

  return humorous_inputs, non_humorous_inputs

def sampleEven(positiveData, negativeData, sample_size_per_class, rand_seed):
  sample_size_per_class = min(sample_size_per_class, len(humorousData), len(nonHumorousData))

  sample_inputs = []
  sample_labels = []

  data = positiveData
  test_size = (len(data) - sample_size_per_class) / len(data)
  sample, _ = train_test_split(data, test_size=test_size, random_state=rand_seed)
  sample_inputs += sample
  sample_labels += [1]*len(sample)


  data = negativeData
  test_size = (len(data) - sample_size_per_class) / len(data)
  sample, _ = train_test_split(data, test_size=test_size, random_state=rand_seed)
  sample_inputs += sample
  sample_labels += [0]*len(sample)

  return sample_inputs, sample_labels

def createBatches(data, batch_size):
  return [data[i:i+batch_size] for i in range(0, len(data), batch_size)]

def testLLAMA(inputs, labels, printResultsEveryN=50):
  resultsData = {
      "truePos": [],
      "trueNeg": [],
      "falsePos": [],
      "falseNeg": [],
  }

  results = {
      "truePos": 0,
      "trueNeg": 0,
      "falsePos": 0,
      "falseNeg": 0,
  }

  correct = 0
  total = 0
  pred = []

  terminators = [
      tokenizer.eos_token_id,
      tokenizer.convert_tokens_to_ids("<|eot_id|>")
  ]

  for i in range(len(inputs)):
    input = inputs[i]
    label = labels[i]

    input_ids = tokenizer.apply_chat_template(
      input,
      add_generation_prompt=True,
      return_tensors="pt"
    ).to(model.device)

    outputs = model.generate(
      input_ids,
      max_new_tokens=50,
      eos_token_id=terminators,
      do_sample=True,
      temperature=0.6,
      top_p=0.9,
      num_return_sequences=1,
    )

    response = outputs[0][input_ids.shape[-1]:]
    response = tokenizer.decode(response, skip_special_tokens=True)
    modelInput = tokenizer.decode(input_ids[0], skip_special_tokens=False)

    resultsDict = {
        "input": modelInput,
        "output": response,
    }


    if str(response) == str(label):
      # true
      if str(label) == "1":
        # pos
        resultsData["truePos"].append(resultsDict)
        results["truePos"] += 1
      else:
        # neg
        resultsData["trueNeg"].append(resultsDict)
        results["trueNeg"] += 1
      correct += 1
    else:
      # false
      if str(label) == "1":
        # pos, pred neg
        resultsData["falseNeg"].append(resultsDict)
        results["falseNeg"] += 1
      else:
        # neg, pred pos
        resultsData["falsePos"].append(resultsDict)
        results["falsePos"] += 1
    pred.append(response)
    total += 1

    if i % printResultsEveryN == 0:
      print(f"Test: {i+1} of  {len(inputs)}")
      print(f"Success rate: {correct / total:.2%}\n")
      print("results data:", results)


  print(f"Final success rate: {correct / total:.2%}")

  # true = [str(i) for i in labels]
  # report = classification_report(y_pred=pred, y_true=true, target_names=["Non-Humorous","Humorous"])
  report = None

  return results, resultsData, pred, report

# %% [markdown]
# ## Defining input formatters

# %%
def transformInput(context, target):
  # if not context:
  #   return transformInputNoContext(target)

  messages = []

  separator = "\n"
  quotation_token = '"'

  # formatted_input = ""

  systemPrmpt = {
      'role': 'system',
      'content': "You are humor classification model, determine whether the target dialogue is humorous using the previous dialogue as context. RESTRICTION: ONLY RESPOND 1 (for humorous) OR 0 (for not humorous)."
  }
  # append systemPrmpt
  messages.append(systemPrmpt)

  # systemPrmpt2 = {
  #     'role': 'system',
  #     'content': ""
  # }
  userPrmpt = {
      'role': 'user',
      'content': ""
  }
  # userPrmpt2 = {
  #     'role': 'user',
  #     'content': ""
  # }
  # asstPrmpt = {
  #     'role': 'assistant',
  #     'content': ""
  # }


  # CONTEXT
  userPrmpt['content'] += "Context:" + separator

  # if entry['Scene'] != current_scene:
  #   current_scene = entry["Scene"]
  #   userPrmpt2['content'] += "The scene changes to: "
  # else:
  #   userPrmpt2['content'] += "The Scene is still: "

  # userPrmpt2['content'] += current_scene + separator

  for entry in context:
    # if current_scene != entry['Scene']:
    #   current_scene = entry["Scene"]
    #   userPrmpt2['content'] += "The scene changes to: " + current_scene + separator

    recipients = entry['Recipients']
    recipients = [i for i in recipients if i != ""]

    recipients_str = ""
    if len(recipients) == 0:
      recipients_str += "to themselves"
    elif len(recipients) == 1:
      recipients_str += recipients[0]
    else:
      recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

    userPrmpt['content'] += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}." + separator

  # TARGET LINE
  userPrmpt['content'] += separator + "Target:" + separator

  # current_scene = context[0]['Scene']
  # userPrmpt['content'] += "Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond '1' for humorous or '0' for not humorous:"
  # userPrmpt['content'] += separator*2

  entry = target

  # if entry['Scene'] != current_scene:
  #   current_scene = entry["Scene"]
  #   userPrmpt['content'] += "The scene changes to: "
  # else:
  #   userPrmpt['content'] += "The Scene is still: "
  # userPrmpt['content'] += current_scene + separator

  recipients = entry['Recipients']
  recipients = [i for i in recipients if i != ""]
  recipients_str = ""
  if len(recipients) == 0:
    recipients_str += "to themselves"
  elif len(recipients) == 1:
    recipients_str += recipients[0]
  else:
    recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]


  userPrmpt['content'] += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}." + separator

  userPrmpt['content'] += separator*2 + "Is the target dialogue humorous (return 1) or not humorous (return 0)?"

  # systemPrmpt2['content'] += "Using the context provided, return '1' if the target_moment was humorous or '0' if the target_moment was not humorous?"
  # append userPrmpt
  messages.append(userPrmpt)

  # asstPrmpt['content'] += "Can you provide some context to help me with this decision?"
  # append asstPrmpt
  # messages.append(asstPrmpt)

  # userPrmpt['content'] += "Context:" + separator

  # if entry['Scene'] != current_scene:
  #   current_scene = entry["Scene"]
  #   userPrmpt2['content'] += "The scene changes to: "
  # else:
  #   userPrmpt2['content'] += "The Scene is still: "

  # userPrmpt2['content'] += current_scene + separator

  # for entry in context:
  #   if current_scene != entry['Scene']:
  #     current_scene = entry["Scene"]
  #     userPrmpt2['content'] += "The scene changes to: " + current_scene + separator

  #   recipients = entry['Recipients']
  #   recipients = [i for i in recipients if i != ""]

  #   recipients_str = ""
  #   if len(recipients) == 0:
  #     recipients_str += "to themselves"
  #   elif len(recipients) == 1:
  #     recipients_str += recipients[0]
  #   else:
  #     recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

  #   userPrmpt2['content'] += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}."
  #   userPrmpt2['content'] += separator

  # # append userPrmpt2
  # messages.append(userPrmpt2)

  # userPrmpt2['content'] += separator + "-" *20 + separator*2

  # systemPrmpt2['content'] += "Using the context provided, return '1' if the target_moment was humorous or '0' if the target_moment was not humorous?"

  # append systemPrmpt2
  # messages.append(systemPrmpt2)

  # messages = [systemPrmpt, userPrmpt, asstPrmpt, ]

  return messages

# %%
def transformInputNoContext(target):
  messages = []

  separator = "\n"
  quotation_token = '"'

  # formatted_input = ""

  systemPrmpt = {
      'role': 'system',
      'content': "You are humor classification model that takes a given line (the target), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."
  }
  # append systemPrmpt
  messages.append(systemPrmpt)

  systemPrmpt2 = {
      'role': 'system',
      'content': ""
  }
  userPrmpt = {
      'role': 'user',
      'content': ""
  }
  userPrmpt2 = {
      'role': 'user',
      'content': ""
  }
  asstPrmpt = {
      'role': 'assistant',
      'content': ""
  }

  # current_scene = context[0]['Scene']

  userPrmpt['content'] += "Is the following moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond '1' for humorous or '0' for not humorous:"
  userPrmpt['content'] += separator*2
  entry = target
  userPrmpt['content'] += "The Scene is: " + entry['Scene'] + separator


  recipients = entry['Recipients']
  recipients_str = ""
  if len(recipients) == 0:
    recipients_str += "to themselves"
  elif len(recipients) == 1:
    recipients_str += recipients[0]
  else:
    recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

  userPrmpt['content'] += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}."



  # append userPrmpt
  messages.append(userPrmpt)

  # asstPrmpt['content'] += "Can you provide some context to help me with this decision?"
  # # append asstPrmpt
  # messages.append(asstPrmpt)

  # userPrmpt2['content'] += "Yes, use the following as context:" + separator*2

  # if entry['Scene'] != current_scene:
  #   current_scene = entry["Scene"]
  #   userPrmpt2['content'] += "The scene changes to: "
  # else:
  #   userPrmpt2['content'] += "The Scene is still: "

  # userPrmpt2['content'] += current_scene + separator

  # for entry in context:
  #   if current_scene != entry['Scene']:
  #     current_scene = entry["Scene"]
  #     userPrmpt2['content'] += "The scene changes to: " + current_scene + separator

  #   recipients = entry['Recipients']
  #   recipients_str = ""
  #   if len(recipients) == 0:
  #     recipients_str += "to themselves"
  #   elif len(recipients) == 1:
  #     recipients_str += recipients[0]
  #   else:
  #     recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

  #   userPrmpt2['content'] += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}."
  #   userPrmpt2['content'] += separator

  # # append userPrmpt2
  # messages.append(userPrmpt2)

  # userPrmpt2['content'] += separator + "-" *20 + separator*2

  # systemPrmpt2['content'] += "Using the context provided, return '1' if the target_moment was humorous or '0' if the target_moment was not humorous?"

  # append systemPrmpt2
  # messages.append(systemPrmpt2)

  # messages = [systemPrmpt, userPrmpt, asstPrmpt, ]

  return messages

# %% [markdown]
# ### Some nShot specific formatters

# %%
def fPathList_TO_ContextsTargetsLabels(filePathList, nSentenceContext):
  humorEntries = []
  nonHumorEntries = []

  for episodePath in filePathList:
    with open(episodePath, 'r') as file:
      data = json.load(file)
      data = [info for (_, info) in data.items()]


      i = nSentenceContext
      while i < len(data):
        entry = {}

        entry['context'] = [data[j] for j in range(i-nSentenceContext, i)]
        entry['target'] = data[i]
        if 'isHumor' in data[i]:
          entry['label'] = 1
          humorEntries.append(entry)
        else:
          entry['label'] = 0
          nonHumorEntries.append(entry)
        i += 1

  return humorEntries, nonHumorEntries

def transformInputNShot(entries, labels):
  # if (len(contexts) != len(targets)) & (len(contexts) != len(labels)):
  #   print("TRANSFORMINPUT nSHOT ERROR, CONTEXTS, TARGETS, LABELS NOT EQUAL LENGTHS")
  #   return

  # if not context:
  #   return transformInputNoContext(target)


  separator = "\n"
  quotation_token = '"'

  formatted_input = "Here are some examples of the task:\n"

  for i in range(len(entries)):
    context = entries[i]['context']
    target = entries[i]['target']
    label = labels[i]

    current_scene = context[-1]['Scene']

    formatted_input += separator*2 + f"Example {i + 1}:" + separator

    # formatted_input += "User: Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond '1' for humorous or '0' for not humorous:"

    formatted_input += "Target moment:" + separator

    entry = target
    if entry['Scene'] != current_scene:
      current_scene = entry["Scene"]
      formatted_input += "The scene changes to: "
    else:
      formatted_input += "The Scene is still: "

    formatted_input += current_scene + separator


    recipients = entry['Recipients']
    recipients = [i for i in recipients if i != ""]

    recipients_str = ""
    if len(recipients) == 0:
      recipients_str += "to themselves"
    elif len(recipients) == 1:
      recipients_str += recipients[0]
    else:
      recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

    formatted_input += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}." + separator

    # formatted_input += "Assistant: Can you provide some context to help me with this decision?" + separator

    # formatted_input += "User: Yes, use the following as context:" + separator*2

    formatted_input += "-"*20 + separator + "Context:" + separator

    if entry['Scene'] != current_scene:
      current_scene = entry["Scene"]
      formatted_input += "The scene changes to: "
    else:
      formatted_input += "The Scene is still: "

    formatted_input += current_scene + separator

    for entry in context:
      if current_scene != entry['Scene']:
        current_scene = entry["Scene"]
        formatted_input += "The scene changes to: " + current_scene + separator

      recipients = entry['Recipients']
      recipients = [i for i in recipients if i != ""]
      recipients_str = ""
      if len(recipients) == 0:
        recipients_str += "to themselves"
      elif len(recipients) == 1:
        recipients_str += recipients[0]
      else:
        recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

      formatted_input += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}." + separator

    formatted_input += "-"*20 + separator
    formatted_input += f"Correct Output: {label}"

  return formatted_input

def addNShotText(input, nShotText):
  returnInput = deepcopy(input)

  if input[0]['role'] != "system":
    print("ERROR: first message in input is not assigned")
    return

  returnInput[0]['content'] += "\n\n" + nShotText

  return returnInput

# %% [markdown]
# # Creating sample data

# %%
filePaths = []
for i in range(5):
  fPath = '/content/info4940-sitcom/cleaned-data/S' + str(i+1)
  filePaths += list_files(fPath)

# getting random number for random state for consistency?
rand_seed1 = 64 # random.randint(1,100)
rand_seed2 = 94 # random.randint(1,100)
rand_seed3 = 69 # random.randint(1,100)
rand_seed4 = 74 # random.randint(1,100)


# print([rand_seed1,rand_seed2,rand_seed3])

# sampling 10 episodes
nSamples = 10
test_size = (len(filePaths) - nSamples) / len(filePaths)
samplePaths, nShotSamplePaths = train_test_split(filePaths, test_size=test_size, random_state=rand_seed1)

# cleaning/transforming inputs
nContext = 5
humorousData, nonHumorousData = fPathList_TO_DialogueWithContext(samplePaths, nContext)
sample_inputs, sample_labels = sampleEven(positiveData=humorousData, negativeData=nonHumorousData, sample_size_per_class=250, rand_seed=rand_seed2)

# shuffling, not necessary but helpful for watching in-progress results
rand_order = [i for i in range(len(sample_inputs))]
random.seed(rand_seed3)
random.shuffle(rand_order)
random.seed(random.randint(1,100))

inputs = [sample_inputs[i] for i in rand_order]
labels = [sample_labels[i] for i in rand_order]

# %% [markdown]
# ## Creating nShotText

# %%
nShot = 16

random.shuffle(nShotSamplePaths)
nShotSamplePaths = nShotSamplePaths[:3]

nShotHumorEntries, nShotNonHumorEntries = fPathList_TO_ContextsTargetsLabels(nShotSamplePaths, nContext)
nShot_sample_entries, nShot_sample_labels = sampleEven(positiveData=nShotHumorEntries, negativeData=nShotNonHumorEntries, sample_size_per_class=math.ceil(nShot/2), rand_seed=rand_seed4)

rand_order = [i for i in range(len(nShot_sample_entries))]
random.shuffle(rand_order)

nShot_sample_entries = [nShot_sample_entries[i] for i in rand_order]
nShot_sample_labels = [nShot_sample_labels[i] for i in rand_order]


nShotText = transformInputNShot(entries=nShot_sample_entries, labels=nShot_sample_labels)
# inputs = [addNShotText(input, nShotText) for input in inputs]

# %% [markdown]
# ### Sample nShot Text

# %%
nShot_sample_entries
# Out:
# [{'context': [{'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The university cafeteria. Raj has the cricket in a jar.',
#     'Recipients': ['Sheldon'],
#     'Speaker': 'Raj',
#     'Dialogue': 'Ugh, Toby, what did you do in a past life to be so disgusting now?',
#     'Dialogue Start Time': '00:12:13:050000',
#     'Dialogue End Time': '00:12:19:050000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The university cafeteria. Raj has the cricket in a jar.',
#     'Recipients': ['Raj'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "His name isn't Toby Toby is an absurd name for a cricket.",
#     'Dialogue Start Time': '00:12:19:050000',
#     'Dialogue End Time': '00:12:23:170000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The university cafeteria. Raj has the cricket in a jar.',
#     'Recipients': ['Sheldon'],
#     'Speaker': 'Raj',
#     'Dialogue': 'What would you name him?',
#     'Dialogue Start Time': '00:12:23:170000',
#     'Dialogue End Time': '00:12:24:170000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The university cafeteria. Raj has the cricket in a jar.',
#     'Recipients': ['Raj'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'An appropriate cricket name. For example, Jiminy.',
#     'Dialogue Start Time': '00:12:24:170000',
#     'Dialogue End Time': '00:12:28:180000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The university cafeteria. Raj has the cricket in a jar.',
#     'Recipients': ['Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': 'All right, Sheldon, here we go. Kleingast\'s Field Guide to North American Insects. Hey, Toby. Right here. See it? The common field cricket, AKA Gryllus assimilis, which is Latin for "suck it, you lose."',
#     'Dialogue Start Time': '00:12:28:180000',
#     'Dialogue End Time': '00:12:44:060000'}],
#   'target': {'EpisodeID': 'The Big Bang_S0302',
#    'Scene': 'The university cafeteria. Raj has the cricket in a jar.',
#    'Recipients': ['Raj', 'Howard'],
#    'Speaker': 'Sheldon',
#    'Dialogue': "Hang on. Voil?. The snowy tree cricket. AKA Oecanthus fultoni, which is Latin for I'll suck nothing.",
#    'Dialogue Start Time': '00:12:44:070000',
#    'Dialogue End Time': '00:12:53:190000',
#    'isHumor': True,
#    'humorDuration': '0:00:01'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Leonard', 'Sheldon'],
#     'Speaker': 'Sheldon ',
#     'Dialogue': "Don't forget the male-pattern baldness.",
#     'Dialogue Start Time': '00:11:11:220000',
#     'Dialogue End Time': '00:11:14:030000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Leonard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'When his uncles sit around the dinner table, they look like a half carton of eggs.',
#     'Dialogue Start Time': '00:11:15:030000',
#     'Dialogue End Time': '00:11:19:020000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Sheldon'],
#     'Speaker': 'Leonard',
#     'Dialogue': "Okay, my uncles are bald, but my Aunt Edna is one of the hairiest women you'll ever meet.",
#     'Dialogue Start Time': '00:11:39:050000',
#     'Dialogue End Time': '00:11:43:220000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Sheldon'],
#     'Speaker': 'Leonard',
#     'Dialogue': 'Sweet lady. Always tickles when she hugs me.',
#     'Dialogue Start Time': '00:11:45:090000',
#     'Dialogue End Time': '00:11:48:160000',
#     'isHumor': True,
#     'humorDuration': '0:00:05'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Sheldon'],
#     'Speaker': 'Leonard',
#     'Dialogue': '- What now? ',
#     'Dialogue Start Time': '00:11:53:200000',
#     'Dialogue End Time': '00:11:56:010000',
#     'isHumor': True,
#     'humorDuration': '0:00:06'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The apartment.',
#    'Recipients': ['Leslie'],
#    'Speaker': 'Leonard',
#    'Dialogue': "I'm sorry about all of Sheldon's interruptions. He can be a bit of an eccentric.",
#    'Dialogue Start Time': '00:12:02:130000',
#    'Dialogue End Time': '00:12:06:180000'},
#   'label': 0},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard and Leslie are kissing.',
#     'Recipients': ['Sheldon', 'Leslie'],
#     'Speaker': 'Leonard',
#     'Dialogue': "Sheldon, don't make that noise. It's disrespectful.",
#     'Dialogue Start Time': '00:18:54:230000',
#     'Dialogue End Time': '00:18:57:200000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard and Leslie are kissing.',
#     'Recipients': ['Leonard', 'Leslie'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'I should hope so. It was a snort of derision.',
#     'Dialogue Start Time': '00:18:58:000000',
#     'Dialogue End Time': '00:19:00:150000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard and Leslie are kissing.',
#     'Recipients': ['Sheldon', 'Leonard'],
#     'Speaker': 'Leslie',
#     'Dialogue': 'You agree with me, right? Loop quantum gravity is the future of physics.',
#     'Dialogue Start Time': '00:19:01:150000',
#     'Dialogue End Time': '00:19:05:120000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard and Leslie are kissing.',
#     'Recipients': ['Sheldon', 'Leslie'],
#     'Speaker': 'Leonard',
#     'Dialogue': 'Sorry, Leslie, I guess I prefer my space stringy, not loopy.',
#     'Dialogue Start Time': '00:19:06:050000',
#     'Dialogue End Time': '00:19:09:160000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard and Leslie are kissing.',
#     'Recipients': ['Sheldon', 'Leonard'],
#     'Speaker': 'Leslie',
#     'Dialogue': "I'm glad I found out the truth about you before this went any further.",
#     'Dialogue Start Time': '00:19:11:010000',
#     'Dialogue End Time': '00:19:14:070000'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The apartment. Leonard and Leslie are kissing.',
#    'Recipients': ['Sheldon', 'Leslie'],
#    'Speaker': 'Leonard',
#    'Dialogue': "Truth? What truth? We're talking about untested hypothes. It's no big deal.",
#    'Dialogue Start Time': '00:19:14:190000',
#    'Dialogue End Time': '00:19:19:080000'},
#   'label': 0},
#  {'context': [{'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The apartment. The guys are playing Wii bowling.',
#     'Recipients': ['Raj', 'Sheldon', 'Leonard'],
#     'Speaker': 'Howard',
#     'Dialogue': "Yeah. It's officially a bro-mance.",
#     'Dialogue Start Time': '00:05:16:100000',
#     'Dialogue End Time': '00:05:18:190000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The apartment. The guys are playing Wii bowling.',
#     'Recipients': ['Raj', 'Sheldon', 'Howard', 'Leonard'],
#     'Speaker': 'Penny ',
#     'Dialogue': 'Are you and Leonard putting up a Christmas tree?',
#     'Dialogue Start Time': '00:05:20:150000',
#     'Dialogue End Time': '00:05:22:210000'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The apartment. The guys are playing Wii bowling.',
#     'Recipients': ['Raj', 'Howard', 'Leonard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "No, because we don't celebrate the ancient pagan festival of Saturnalia.",
#     'Dialogue Start Time': '00:05:23:010000',
#     'Dialogue End Time': '00:05:27:030000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The apartment. The guys are playing Wii bowling.',
#     'Recipients': ['Raj', 'Sheldon', 'Howard', 'Leonard'],
#     'Speaker': 'Penny',
#     'Dialogue': '- Saturnalia? ',
#     'Dialogue Start Time': '00:05:28:210000',
#     'Dialogue End Time': '00:05:31:080000'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The apartment. The guys are playing Wii bowling.',
#     'Recipients': ['Raj', 'Howard', 'Leonard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'In the pre-Christian era, as the winter solstice approached and the plants died, pagans brought evergreen boughs into their homes as an act of sympathetic magic, intended to guard the life essences of the plants until spring. This custom was later appropriated by Northern Europeans and eventually it becomes the so-called Christmas tree.',
#     'Dialogue Start Time': '00:05:36:130000',
#     'Dialogue End Time': '00:05:53:130000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'}],
#   'target': {'EpisodeID': 'The Big Bang_S0211',
#    'Scene': 'The apartment. The guys are playing Wii bowling.',
#    'Recipients': ['Raj', 'Sheldon', 'Leonard'],
#    'Speaker': 'Howard',
#    'Dialogue': 'And that, Charlie Brown, is what boredom is all about.',
#    'Dialogue Start Time': '00:05:55:180000',
#    'Dialogue End Time': '00:05:59:010000',
#    'isHumor': True,
#    'humorDuration': '0:00:02'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Leonard', 'Eric', 'Penny'],
#     'Speaker': 'Eric ',
#     'Dialogue': 'From the Charlie Brown cartoons?',
#     'Dialogue Start Time': '00:12:46:170000',
#     'Dialogue End Time': '00:12:48:180000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Leonard', 'Eric'],
#     'Speaker': 'Penny',
#     'Dialogue': 'No, he was some kind of scientist. Let me start again. - Hey, Leonard. ',
#     'Dialogue Start Time': '00:12:50:050000',
#     'Dialogue End Time': '00:12:55:090000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Eric', 'Penny'],
#     'Speaker': 'Leonard',
#     'Dialogue': '- Hello.',
#     'Dialogue Start Time': '00:12:53:230000',
#     'Dialogue End Time': '00:12:55:090000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Leonard', 'Eric'],
#     'Speaker': 'Penny',
#     'Dialogue': '- Leslie. ',
#     'Dialogue Start Time': '00:12:55:120000',
#     'Dialogue End Time': '00:12:56:210000',
#     'isHumor': True,
#     'humorDuration': '0:00:05'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leslie', 'Eric', 'Penny'],
#     'Speaker': 'Leonard',
#     'Dialogue': 'Okay, well... good night.',
#     'Dialogue Start Time': '00:13:01:100000',
#     'Dialogue End Time': '00:13:03:120000',
#     'isHumor': True,
#     'humorDuration': '0:00:03'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The apartment.',
#    'Recipients': ['Leslie', 'Leonard', 'Eric', 'Penny'],
#    'Speaker': 'Penny ',
#    'Dialogue': 'Okay, good night.',
#    'Dialogue Start Time': '00:13:06:130000',
#    'Dialogue End Time': '00:13:07:200000',
#    'isHumor': True,
#    'humorDuration': '0:00:03'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Howard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'In 1890, Emile Dolbear determined that there was a fixed relationship between the number of chirps per minute of the snowy tree cricket and the ambient temperature. A precise relationship that is not present with ordinary field crickets.',
#     'Dialogue Start Time': '00:06:25:170000',
#     'Dialogue End Time': '00:06:36:170000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Howard', 'Sheldon'],
#     'Speaker': 'Raj',
#     'Dialogue': 'How do you know what the exact temperature of the room is?',
#     'Dialogue Start Time': '00:06:36:170000',
#     'Dialogue End Time': '00:06:39:060000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Howard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "Under the terms of my roommate agreement with Leonard, I've had unilateral control of the thermostat ever since the sweaty night of '06.",
#     'Dialogue Start Time': '00:06:39:060000',
#     'Dialogue End Time': '00:06:45:180000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': "Okay, you were right about wolverine and bone claws, but you're wrong about the cricket.",
#     'Dialogue Start Time': '00:06:45:180000',
#     'Dialogue End Time': '00:06:52:180000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Howard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "Howard, don't embarrass yourself. The science chirps for itself. (chuckling): Humorous word play.",
#     'Dialogue Start Time': '00:06:52:180000',
#     'Dialogue End Time': '00:07:00:070000'}],
#   'target': {'EpisodeID': 'The Big Bang_S0302',
#    'Scene': ' The apartment.',
#    'Recipients': ['Raj', 'Sheldon'],
#    'Speaker': 'Howard',
#    'Dialogue': 'No, no, not this time. I know insects, my friend. I spent many childhood years capturing them with nets, putting them in glass jars, sticking pins through them, mounting them on corrugated cardboard with Dymo labels underneath, identifying the genus and species. In Latin.',
#    'Dialogue Start Time': '00:07:00:070000',
#    'Dialogue End Time': '00:07:16:080000',
#    'isHumor': True,
#    'humorDuration': '0:00:02'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The Entomology Department.',
#     'Recipients': ['Raj', 'Howard', 'Sheldon', 'ProfCrawley'],
#     'Speaker': 'Prof Crawley',
#     'Dialogue': "What's your deal? Are they planning to outsource my job to Bangalore?",
#     'Dialogue Start Time': '00:15:26:160000',
#     'Dialogue End Time': '00:15:32:160000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The Entomology Department.',
#     'Recipients': ['Howard', 'Sheldon', 'ProfCrawley'],
#     'Speaker': 'Raj',
#     'Dialogue': "I'm from New Delhi.",
#     'Dialogue Start Time': '00:15:34:040000',
#     'Dialogue End Time': '00:15:36:160000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The Entomology Department.',
#     'Recipients': ['Howard', 'Sheldon', 'ProfCrawley'],
#     'Speaker': 'Raj',
#     'Dialogue': 'Maybe you should find another entomologist.',
#     'Dialogue Start Time': '00:15:37:040000',
#     'Dialogue End Time': '00:15:38:160000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The Entomology Department.',
#     'Recipients': ['Raj', 'Howard', 'ProfCrawley'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "No, no. We're here. Let's settle this. Professor, can you identify our cricket?",
#     'Dialogue Start Time': '00:15:39:040000',
#     'Dialogue End Time': '00:15:43:170000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The Entomology Department.',
#     'Recipients': ['Raj', 'Howard', 'Sheldon', 'ProfCrawley'],
#     'Speaker': 'Prof Crawley',
#     'Dialogue': "Of course I can. I can identify every insect and arachnid on the planet. Not that that's going to keep me from having to move in with my daughter in Oxnard. And we're not talking Oxnard at the beach. No! We're talking Oxnard in the onion fields.",
#     'Dialogue Start Time': '00:15:43:170000',
#     'Dialogue End Time': '00:16:01:180000',
#     'isHumor': True,
#     'humorDuration': '0:00:03'}],
#   'target': {'EpisodeID': 'The Big Bang_S0302',
#    'Scene': 'The Entomology Department.',
#    'Recipients': ['Raj', 'Sheldon', 'ProfCrawley'],
#    'Speaker': 'Howard',
#    'Dialogue': 'Well, could you look at Toby?',
#    'Dialogue Start Time': '00:16:04:180000',
#    'Dialogue End Time': '00:16:07:060000'},
#   'label': 0},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leonard', 'Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': 'Yeah, so? Be a tool.',
#     'Dialogue Start Time': '00:04:37:210000',
#     'Dialogue End Time': '00:04:39:140000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leonard', 'Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': 'Go get yourself a little rebound stress release.',
#     'Dialogue Start Time': '00:04:41:160000',
#     'Dialogue End Time': '00:04:44:100000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leonard', 'Howard', 'Sheldon'],
#     'Speaker': 'Raj',
#     'Dialogue': 'Technically, it would only be rebound if he and Penny had actually engaged in physical intimacy.',
#     'Dialogue Start Time': '00:04:44:150000',
#     'Dialogue End Time': '00:04:48:220000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leonard', 'Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': 'Like you and Richard the slave girl?',
#     'Dialogue Start Time': '00:04:49:000000',
#     'Dialogue End Time': '00:04:51:130000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment.',
#     'Recipients': ['Leonard', 'Howard', 'Sheldon'],
#     'Speaker': 'Raj',
#     'Dialogue': 'I bought him dinner and we kissed once! That was it. And he told me his name was Kimberly.',
#     'Dialogue Start Time': '00:04:53:040000',
#     'Dialogue End Time': '00:04:59:150000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The university cafeteria.',
#    'Recipients': ['Leonard'],
#    'Speaker': 'Sheldon',
#    'Dialogue': "You know how I know we're not in the matrix?",
#    'Dialogue Start Time': '00:05:04:090000',
#    'Dialogue End Time': '00:05:06:230000',
#    'isHumor': True,
#    'humorDuration': '0:00:05'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Leonard', 'Howard', 'Raj', 'Penny', 'Eric'],
#     'Speaker': 'Eric ',
#     'Dialogue': 'I like your hat.',
#     'Dialogue Start Time': '00:01:27:220000',
#     'Dialogue End Time': '00:01:29:040000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Leonard', 'Raj'],
#     'Speaker': 'Howard',
#     'Dialogue': 'Thanks, my mom made it.',
#     'Dialogue Start Time': '00:01:30:170000',
#     'Dialogue End Time': '00:01:32:060000',
#     'isHumor': True,
#     'humorDuration': '0:00:03'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Leonard', 'Raj'],
#     'Speaker': 'Howard',
#     'Dialogue': 'Penny with a new guy, très awkward.',
#     'Dialogue Start Time': '00:01:35:020000',
#     'Dialogue End Time': '00:01:37:100000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Howard', 'Raj'],
#     'Speaker': 'Leonard',
#     'Dialogue': "It wasn't awkward. It wasn't fun.",
#     'Dialogue Start Time': '00:01:39:030000',
#     'Dialogue End Time': '00:01:43:160000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Howard', 'Raj'],
#     'Speaker': 'Leonard',
#     'Dialogue': "Besides, what's the big deal? We dated, we stopped dating, and now we're both moving on.",
#     'Dialogue Start Time': '00:01:44:100000',
#     'Dialogue End Time': '00:01:49:060000'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#    'Recipients': ['Sheldon', 'Leonard', 'Howard'],
#    'Speaker': 'Raj',
#    'Dialogue': "By moving on, do you mean she's going out with other men and you spent the afternoon making 15th-century soap with Wolowitz?",
#    'Dialogue Start Time': '00:01:49:090000',
#    'Dialogue End Time': '00:01:55:150000',
#    'isHumor': True,
#    'humorDuration': '0:00:01'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Sheldon'],
#     'Speaker': 'Leonard',
#     'Dialogue': "It's a date. I have a date coming over.",
#     'Dialogue Start Time': '00:07:59:060000',
#     'Dialogue End Time': '00:08:01:110000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Leonard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "You can't blame me for not jumping to that conclusion.",
#     'Dialogue Start Time': '00:08:03:060000',
#     'Dialogue End Time': '00:08:06:080000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Sheldon'],
#     'Speaker': 'Leonard',
#     'Dialogue': "Why? What's so unusual about me having a date?",
#     'Dialogue Start Time': '00:08:08:140000',
#     'Dialogue End Time': '00:08:10:230000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Sheldon'],
#     'Speaker': 'Leonard',
#     'Dialogue': "- All right, all right. Nevertheless, I have one now and I'd appreciate it if you would, make yourself scarce.",
#     'Dialogue Start Time': '00:08:11:040000',
#     'Dialogue End Time': '00:08:18:150000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Leonard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "I'm a published theoretical physicist with two doctorates and an IQ which can't be accurely measured by normal tests. How much scarcer could I be?",
#     'Dialogue Start Time': '00:08:19:010000',
#     'Dialogue End Time': '00:08:26:150000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#    'Recipients': ['Sheldon'],
#    'Speaker': 'Leonard',
#    'Dialogue': 'You know what I mean. Could you just give us a little privacy?',
#    'Dialogue Start Time': '00:08:28:030000',
#    'Dialogue End Time': '00:08:30:160000'},
#   'label': 0},
#  {'context': [{'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Howard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'Thatis a snowy tree cricket. Oecanthus fultoni. I was done with Latin by fifth grade.',
#     'Dialogue Start Time': '00:07:24:210000',
#     'Dialogue End Time': '00:07:31:210000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': "Okay, okay, tell you what. I am willing to bet anything that's an ordinary field cricket.",
#     'Dialogue Start Time': '00:07:31:210000',
#     'Dialogue End Time': '00:07:36:090000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Howard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "I can't take your money.",
#     'Dialogue Start Time': '00:07:36:210000',
#     'Dialogue End Time': '00:07:38:210000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': "What's the matter, you chicken?",
#     'Dialogue Start Time': '00:07:38:210000',
#     'Dialogue End Time': '00:07:40:090000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Howard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "I've always found that an inappropriate slur. Chickens are not, by nature, at all timid. In fact, when I was young, my neighbor's chicken got loose and chased me up the big elm tree in front of our house.",
#     'Dialogue Start Time': '00:07:40:100000',
#     'Dialogue End Time': '00:07:51:220000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'}],
#   'target': {'EpisodeID': 'The Big Bang_S0302',
#    'Scene': ' The apartment.',
#    'Recipients': ['Howard', 'Sheldon'],
#    'Speaker': 'Raj',
#    'Dialogue': ". Chickens can't climb trees",
#    'Dialogue Start Time': '00:07:53:100000',
#    'Dialogue End Time': '00:07:55:100000'},
#   'label': 0},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Leonard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'Why should I leave? This is my apartment, too.',
#     'Dialogue Start Time': '00:08:39:200000',
#     'Dialogue End Time': '00:08:41:200000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Sheldon'],
#     'Speaker': 'Leonard',
#     'Dialogue': "I know, and if science ever discovers a second member of your species and you two would like some privacy, I'd be more than happy to get out of your way.",
#     'Dialogue Start Time': '00:08:41:230000',
#     'Dialogue End Time': '00:08:49:090000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.',
#     'Recipients': ['Leonard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'Well, all right then.',
#     'Dialogue Start Time': '00:08:51:100000',
#     'Dialogue End Time': '00:08:52:190000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.',
#     'Recipients': ['Sheldon'],
#     'Speaker': 'Penny',
#     'Dialogue': 'What are you doing?',
#     'Dialogue Start Time': '00:08:58:190000',
#     'Dialogue End Time': '00:08:59:230000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.',
#     'Recipients': ['Penny'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'Playing Super Mario on a poorly coded Nintendo 64 emulator.',
#     'Dialogue Start Time': '00:09:00:040000',
#     'Dialogue End Time': '00:09:04:170000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.',
#    'Recipients': ['Sheldon'],
#    'Speaker': 'Penny',
#    'Dialogue': 'Why are you doing it on the stairs?',
#    'Dialogue Start Time': '00:09:06:030000',
#    'Dialogue End Time': '00:09:07:210000'},
#   'label': 0},
#  {'context': [{'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Penny'],
#     'Speaker': 'Leonard',
#     'Dialogue': 'Actually, ethyl alcohol inhibits electrical conduction in the nerve cells and stimulates reuptake receptors of inhibitory neurotransmitters like gamma-aminobutyric acid.',
#     'Dialogue Start Time': '00:05:14:000000',
#     'Dialogue End Time': '00:05:24:130000',
#     'isHumor': True,
#     'humorDuration': '0:00:03'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Leonard'],
#     'Speaker': 'Penny',
#     'Dialogue': "Don't talk, just drink.",
#     'Dialogue Start Time': '00:05:27:010000',
#     'Dialogue End Time': '00:05:29:130000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Sheldon'],
#     'Speaker': 'Howard',
#     'Dialogue': "No, you're misunderstanding A shiksa goddess isn't an actual goddess And we don't pray to them. We prey on them.",
#     'Dialogue Start Time': '00:05:32:010000',
#     'Dialogue End Time': '00:05:42:140000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Howard', 'Sheldon'],
#     'Speaker': 'Raj',
#     'Dialogue': "Whatever, dude. The point is, Leonard's got one and you don't.",
#     'Dialogue Start Time': '00:05:42:140000',
#     'Dialogue End Time': '00:05:46:140000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': ' The apartment.',
#     'Recipients': ['Raj', 'Howard'],
#     'Speaker': 'Sheldon',
#     'Dialogue': "Is this it? It was inappropriate to discuss Leonard and Penny's sex life in front of Leonard and Penny. Oh, good!",
#     'Dialogue Start Time': '00:05:47:020000',
#     'Dialogue End Time': '00:05:56:150000',
#     'isHumor': True,
#     'humorDuration': '0:00:02'}],
#   'target': {'EpisodeID': 'The Big Bang_S0302',
#    'Scene': ' The apartment.',
#    'Recipients': ['Raj', 'Howard'],
#    'Speaker': 'Sheldon',
#    'Dialogue': 'Now I can eat.',
#    'Dialogue Start Time': '00:05:58:030000',
#    'Dialogue End Time': '00:05:59:150000',
#    'isHumor': True,
#    'humorDuration': '0:00:07'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Leonard', 'Howard', 'Raj', 'Penny', 'Eric'],
#     'Speaker': 'Penny ',
#     'Dialogue': 'Hi, guys.',
#     'Dialogue Start Time': '00:00:56:220000',
#     'Dialogue End Time': '00:00:57:220000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Leonard', 'Howard', 'Raj', 'Eric'],
#     'Speaker': 'Penny',
#     'Dialogue': "Looks like you've been to the renaissance fair... I'm hoping.",
#     'Dialogue Start Time': '00:00:58:040000',
#     'Dialogue End Time': '00:01:01:120000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Leonard', 'Howard', 'Raj', 'Penny', 'Eric'],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'Renaissance fair? More of a medieval, slash, Age of Enlightenment, slash, any-excuse-to-wear-a-codpiece fair.',
#     'Dialogue Start Time': '00:01:02:140000',
#     'Dialogue End Time': '00:01:08:180000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Leonard', 'Howard', 'Raj', 'Eric'],
#     'Speaker': 'Penny',
#     'Dialogue': 'Okay, fine, whatever. This is my friend Eric.',
#     'Dialogue Start Time': '00:01:09:220000',
#     'Dialogue End Time': '00:01:12:050000'},
#    {'EpisodeID': 'The Big Bang_S0202',
#     'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#     'Recipients': ['Sheldon', 'Howard', 'Raj', 'Penny', 'Eric'],
#     'Speaker': 'Leonard',
#     'Dialogue': '- Hey. So, yeah, good to see you.',
#     'Dialogue Start Time': '00:01:12:160000',
#     'Dialogue End Time': '00:01:19:200000'}],
#   'target': {'EpisodeID': 'The Big Bang_S0202',
#    'Scene': 'The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.',
#    'Recipients': ['Sheldon', 'Leonard', 'Howard', 'Raj', 'Eric'],
#    'Speaker': 'Penny',
#    'Dialogue': "It's good to see you, too.",
#    'Dialogue Start Time': '00:01:21:140000',
#    'Dialogue End Time': '00:01:23:010000',
#    'isHumor': True,
#    'humorDuration': '0:00:01'},
#   'label': 1},
#  {'context': [{'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The apartment',
#     'Recipients': ['Sheldon', ''],
#     'Speaker': 'Leonard',
#     'Dialogue': "Right, right. You're saying you talked to Penny?",
#     'Dialogue Start Time': '00:19:43:060000',
#     'Dialogue End Time': '00:19:46:060000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The apartment',
#     'Recipients': ['Leonard', ''],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'Ye-Yes.',
#     'Dialogue Start Time': '00:19:46:060000',
#     'Dialogue End Time': '00:19:47:180000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The apartment',
#     'Recipients': ['Sheldon', ''],
#     'Speaker': 'Leonard',
#     'Dialogue': 'Interesting.',
#     'Dialogue Start Time': '00:19:47:180000',
#     'Dialogue End Time': '00:19:48:060000'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The apartment',
#     'Recipients': ['Leonard', ''],
#     'Speaker': 'Sheldon',
#     'Dialogue': 'Hardly.',
#     'Dialogue Start Time': '00:19:48:060000',
#     'Dialogue End Time': '00:19:50:060000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0302',
#     'Scene': 'The apartment',
#     'Recipients': ['Sheldon', ''],
#     'Speaker': 'Leonard',
#     'Dialogue': 'Excuse me.',
#     'Dialogue Start Time': '00:19:50:070000',
#     'Dialogue End Time': '00:19:51:070000'}],
#   'target': {'EpisodeID': 'The Big Bang_S0302',
#    'Scene': 'The apartment',
#    'Recipients': ['Leonard', ''],
#    'Speaker': 'Sheldon',
#    'Dialogue': 'Have I crossed some sort of line again?',
#    'Dialogue Start Time': '00:19:51:070000',
#    'Dialogue End Time': '00:19:53:190000'},
#   'label': 0},
#  {'context': [{'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The stairwell.',
#     'Recipients': ['David', 'Leonard'],
#     'Speaker': 'Penny',
#     'Dialogue': 'Sweetie, sweetie, Dave was talking.',
#     'Dialogue Start Time': '00:08:45:120000',
#     'Dialogue End Time': '00:08:47:170000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The stairwell.',
#     'Recipients': ['David', 'Leonard'],
#     'Speaker': 'Penny',
#     'Dialogue': 'You know, I love science.',
#     'Dialogue Start Time': '00:08:48:200000',
#     'Dialogue End Time': '00:08:50:180000'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The stairwell.',
#     'Recipients': ['David', 'Penny'],
#     'Speaker': 'Leonard',
#     'Dialogue': '- Since when? ',
#     'Dialogue Start Time': '00:08:50:210000',
#     'Dialogue End Time': '00:08:52:160000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The stairwell.',
#     'Recipients': ['David', 'Leonard'],
#     'Speaker': 'Penny',
#     'Dialogue': 'Call me a geek, but I am just nuts for the whole subatomic particle thing.',
#     'Dialogue Start Time': '00:08:53:130000',
#     'Dialogue End Time': '00:08:58:030000'},
#    {'EpisodeID': 'The Big Bang_S0211',
#     'Scene': 'The stairwell.',
#     'Recipients': ['Leonard', 'Penny'],
#     'Speaker': 'David',
#     'Dialogue': 'The last thing I would ever call you is a geek.',
#     'Dialogue Start Time': '00:08:58:110000',
#     'Dialogue End Time': '00:09:00:170000',
#     'isHumor': True,
#     'humorDuration': '0:00:01'}],
#   'target': {'EpisodeID': 'The Big Bang_S0211',
#    'Scene': 'The stairwell.',
#    'Recipients': ['David', 'Leonard'],
#    'Speaker': 'Penny',
#    'Dialogue': "Well, that's what I am... queen of the nerds.",
#    'Dialogue Start Time': '00:09:01:050000',
#    'Dialogue End Time': '00:09:03:180000'},
#   'label': 0}]

# %%
print(nShotText)
# Out:
# Here are some examples of the task:
#
#
# Example 1:
# Target moment:
# The Scene is still: The university cafeteria. Raj has the cricket in a jar.
# Sheldon says "Hang on. Voil?. The snowy tree cricket. AKA Oecanthus fultoni, which is Latin for I'll suck nothing." to Raj and Howard.
# --------------------
# Context:
# The Scene is still: The university cafeteria. Raj has the cricket in a jar.
# Raj says "Ugh, Toby, what did you do in a past life to be so disgusting now?" to Sheldon.
# Sheldon says "His name isn't Toby Toby is an absurd name for a cricket." to Raj.
# Raj says "What would you name him?" to Sheldon.
# Sheldon says "An appropriate cricket name. For example, Jiminy." to Raj.
# Howard says "All right, Sheldon, here we go. Kleingast's Field Guide to North American Insects. Hey, Toby. Right here. See it? The common field cricket, AKA Gryllus assimilis, which is Latin for "suck it, you lose."" to Raj and Sheldon.
# --------------------
# Correct Output: 1
#
# Example 2:
# Target moment:
# The Scene is still: The apartment.
# Leonard says "I'm sorry about all of Sheldon's interruptions. He can be a bit of an eccentric." to Leslie.
# --------------------
# Context:
# The Scene is still: The apartment.
# Sheldon  says "Don't forget the male-pattern baldness." to Leslie, Leonard and Sheldon.
# Sheldon says "When his uncles sit around the dinner table, they look like a half carton of eggs." to Leslie and Leonard.
# Leonard says "Okay, my uncles are bald, but my Aunt Edna is one of the hairiest women you'll ever meet." to Leslie and Sheldon.
# Leonard says "Sweet lady. Always tickles when she hugs me." to Leslie and Sheldon.
# Leonard says "- What now? " to Leslie and Sheldon.
# --------------------
# Correct Output: 0
#
# Example 3:
# Target moment:
# The Scene is still: The apartment. Leonard and Leslie are kissing.
# Leonard says "Truth? What truth? We're talking about untested hypothes. It's no big deal." to Sheldon and Leslie.
# --------------------
# Context:
# The Scene is still: The apartment. Leonard and Leslie are kissing.
# Leonard says "Sheldon, don't make that noise. It's disrespectful." to Sheldon and Leslie.
# Sheldon says "I should hope so. It was a snort of derision." to Leonard and Leslie.
# Leslie says "You agree with me, right? Loop quantum gravity is the future of physics." to Sheldon and Leonard.
# Leonard says "Sorry, Leslie, I guess I prefer my space stringy, not loopy." to Sheldon and Leslie.
# Leslie says "I'm glad I found out the truth about you before this went any further." to Sheldon and Leonard.
# --------------------
# Correct Output: 0
#
# Example 4:
# Target moment:
# The Scene is still: The apartment. The guys are playing Wii bowling.
# Howard says "And that, Charlie Brown, is what boredom is all about." to Raj, Sheldon and Leonard.
# --------------------
# Context:
# The Scene is still: The apartment. The guys are playing Wii bowling.
# Howard says "Yeah. It's officially a bro-mance." to Raj, Sheldon and Leonard.
# Penny  says "Are you and Leonard putting up a Christmas tree?" to Raj, Sheldon, Howard and Leonard.
# Sheldon says "No, because we don't celebrate the ancient pagan festival of Saturnalia." to Raj, Howard and Leonard.
# Penny says "- Saturnalia? " to Raj, Sheldon, Howard and Leonard.
# Sheldon says "In the pre-Christian era, as the winter solstice approached and the plants died, pagans brought evergreen boughs into their homes as an act of sympathetic magic, intended to guard the life essences of the plants until spring. This custom was later appropriated by Northern Europeans and eventually it becomes the so-called Christmas tree." to Raj, Howard and Leonard.
# --------------------
# Correct Output: 1
#
# Example 5:
# Target moment:
# The Scene is still: The apartment.
# Penny  says "Okay, good night." to Leslie, Leonard, Eric and Penny.
# --------------------
# Context:
# The Scene is still: The apartment.
# Eric  says "From the Charlie Brown cartoons?" to Leslie, Leonard, Eric and Penny.
# Penny says "No, he was some kind of scientist. Let me start again. - Hey, Leonard. " to Leslie, Leonard and Eric.
# Leonard says "- Hello." to Leslie, Eric and Penny.
# Penny says "- Leslie. " to Leslie, Leonard and Eric.
# Leonard says "Okay, well... good night." to Leslie, Eric and Penny.
# --------------------
# Correct Output: 1
#
# Example 6:
# Target moment:
# The Scene is still:  The apartment.
# Howard says "No, no, not this time. I know insects, my friend. I spent many childhood years capturing them with nets, putting them in glass jars, sticking pins through them, mounting them on corrugated cardboard with Dymo labels underneath, identifying the genus and species. In Latin." to Raj and Sheldon.
# --------------------
# Context:
# The Scene is still:  The apartment.
# Sheldon says "In 1890, Emile Dolbear determined that there was a fixed relationship between the number of chirps per minute of the snowy tree cricket and the ambient temperature. A precise relationship that is not present with ordinary field crickets." to Raj and Howard.
# Raj says "How do you know what the exact temperature of the room is?" to Howard and Sheldon.
# Sheldon says "Under the terms of my roommate agreement with Leonard, I've had unilateral control of the thermostat ever since the sweaty night of '06." to Raj and Howard.
# Howard says "Okay, you were right about wolverine and bone claws, but you're wrong about the cricket." to Raj and Sheldon.
# Sheldon says "Howard, don't embarrass yourself. The science chirps for itself. (chuckling): Humorous word play." to Raj and Howard.
# --------------------
# Correct Output: 1
#
# Example 7:
# Target moment:
# The Scene is still: The Entomology Department.
# Howard says "Well, could you look at Toby?" to Raj, Sheldon and ProfCrawley.
# --------------------
# Context:
# The Scene is still: The Entomology Department.
# Prof Crawley says "What's your deal? Are they planning to outsource my job to Bangalore?" to Raj, Howard, Sheldon and ProfCrawley.
# Raj says "I'm from New Delhi." to Howard, Sheldon and ProfCrawley.
# Raj says "Maybe you should find another entomologist." to Howard, Sheldon and ProfCrawley.
# Sheldon says "No, no. We're here. Let's settle this. Professor, can you identify our cricket?" to Raj, Howard and ProfCrawley.
# Prof Crawley says "Of course I can. I can identify every insect and arachnid on the planet. Not that that's going to keep me from having to move in with my daughter in Oxnard. And we're not talking Oxnard at the beach. No! We're talking Oxnard in the onion fields." to Raj, Howard, Sheldon and ProfCrawley.
# --------------------
# Correct Output: 0
#
# Example 8:
# Target moment:
# The scene changes to: The university cafeteria.
# Sheldon says "You know how I know we're not in the matrix?" to Leonard.
# --------------------
# Context:
# The Scene is still: The university cafeteria.
# The scene changes to: The apartment.
# Howard says "Yeah, so? Be a tool." to Leonard, Raj and Sheldon.
# Howard says "Go get yourself a little rebound stress release." to Leonard, Raj and Sheldon.
# Raj says "Technically, it would only be rebound if he and Penny had actually engaged in physical intimacy." to Leonard, Howard and Sheldon.
# Howard says "Like you and Richard the slave girl?" to Leonard, Raj and Sheldon.
# Raj says "I bought him dinner and we kissed once! That was it. And he told me his name was Kimberly." to Leonard, Howard and Sheldon.
# --------------------
# Correct Output: 1
#
# Example 9:
# Target moment:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Raj says "By moving on, do you mean she's going out with other men and you spent the afternoon making 15th-century soap with Wolowitz?" to Sheldon, Leonard and Howard.
# --------------------
# Context:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Eric  says "I like your hat." to Sheldon, Leonard, Howard, Raj, Penny and Eric.
# Howard says "Thanks, my mom made it." to Sheldon, Leonard and Raj.
# Howard says "Penny with a new guy, très awkward." to Sheldon, Leonard and Raj.
# Leonard says "It wasn't awkward. It wasn't fun." to Sheldon, Howard and Raj.
# Leonard says "Besides, what's the big deal? We dated, we stopped dating, and now we're both moving on." to Sheldon, Howard and Raj.
# --------------------
# Correct Output: 1
#
# Example 10:
# Target moment:
# The Scene is still: The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.
# Leonard says "You know what I mean. Could you just give us a little privacy?" to Sheldon.
# --------------------
# Context:
# The Scene is still: The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.
# Leonard says "It's a date. I have a date coming over." to Sheldon.
# Sheldon says "You can't blame me for not jumping to that conclusion." to Leonard.
# Leonard says "Why? What's so unusual about me having a date?" to Sheldon.
# Leonard says "- All right, all right. Nevertheless, I have one now and I'd appreciate it if you would, make yourself scarce." to Sheldon.
# Sheldon says "I'm a published theoretical physicist with two doctorates and an IQ which can't be accurely measured by normal tests. How much scarcer could I be?" to Leonard.
# --------------------
# Correct Output: 0
#
# Example 11:
# Target moment:
# The Scene is still:  The apartment.
# Raj says ". Chickens can't climb trees" to Howard and Sheldon.
# --------------------
# Context:
# The Scene is still:  The apartment.
# Sheldon says "Thatis a snowy tree cricket. Oecanthus fultoni. I was done with Latin by fifth grade." to Raj and Howard.
# Howard says "Okay, okay, tell you what. I am willing to bet anything that's an ordinary field cricket." to Raj and Sheldon.
# Sheldon says "I can't take your money." to Raj and Howard.
# Howard says "What's the matter, you chicken?" to Raj and Sheldon.
# Sheldon says "I've always found that an inappropriate slur. Chickens are not, by nature, at all timid. In fact, when I was young, my neighbor's chicken got loose and chased me up the big elm tree in front of our house." to Raj and Howard.
# --------------------
# Correct Output: 0
#
# Example 12:
# Target moment:
# The Scene is still: The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.
# Penny says "Why are you doing it on the stairs?" to Sheldon.
# --------------------
# Context:
# The Scene is still: The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.
# The scene changes to: The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.
# Sheldon says "Why should I leave? This is my apartment, too." to Leonard.
# Leonard says "I know, and if science ever discovers a second member of your species and you two would like some privacy, I'd be more than happy to get out of your way." to Sheldon.
# Sheldon says "Well, all right then." to Leonard.
# The scene changes to: The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.
# Penny says "What are you doing?" to Sheldon.
# Sheldon says "Playing Super Mario on a poorly coded Nintendo 64 emulator." to Penny.
# --------------------
# Correct Output: 0
#
# Example 13:
# Target moment:
# The Scene is still:  The apartment.
# Sheldon says "Now I can eat." to Raj and Howard.
# --------------------
# Context:
# The Scene is still:  The apartment.
# Leonard says "Actually, ethyl alcohol inhibits electrical conduction in the nerve cells and stimulates reuptake receptors of inhibitory neurotransmitters like gamma-aminobutyric acid." to Penny.
# Penny says "Don't talk, just drink." to Leonard.
# Howard says "No, you're misunderstanding A shiksa goddess isn't an actual goddess And we don't pray to them. We prey on them." to Raj and Sheldon.
# Raj says "Whatever, dude. The point is, Leonard's got one and you don't." to Howard and Sheldon.
# Sheldon says "Is this it? It was inappropriate to discuss Leonard and Penny's sex life in front of Leonard and Penny. Oh, good!" to Raj and Howard.
# --------------------
# Correct Output: 1
#
# Example 14:
# Target moment:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Penny says "It's good to see you, too." to Sheldon, Leonard, Howard, Raj and Eric.
# --------------------
# Context:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Penny  says "Hi, guys." to Sheldon, Leonard, Howard, Raj, Penny and Eric.
# Penny says "Looks like you've been to the renaissance fair... I'm hoping." to Sheldon, Leonard, Howard, Raj and Eric.
# Sheldon says "Renaissance fair? More of a medieval, slash, Age of Enlightenment, slash, any-excuse-to-wear-a-codpiece fair." to Leonard, Howard, Raj, Penny and Eric.
# Penny says "Okay, fine, whatever. This is my friend Eric." to Sheldon, Leonard, Howard, Raj and Eric.
# Leonard says "- Hey. So, yeah, good to see you." to Sheldon, Howard, Raj, Penny and Eric.
# --------------------
# Correct Output: 1
#
# Example 15:
# Target moment:
# The Scene is still: The apartment
# Sheldon says "Have I crossed some sort of line again?" to Leonard.
# --------------------
# Context:
# The Scene is still: The apartment
# Leonard says "Right, right. You're saying you talked to Penny?" to Sheldon.
# Sheldon says "Ye-Yes." to Leonard.
# Leonard says "Interesting." to Sheldon.
# Sheldon says "Hardly." to Leonard.
# Leonard says "Excuse me." to Sheldon.
# --------------------
# Correct Output: 0
#
# Example 16:
# Target moment:
# The Scene is still: The stairwell.
# Penny says "Well, that's what I am... queen of the nerds." to David and Leonard.
# --------------------
# Context:
# The Scene is still: The stairwell.
# Penny says "Sweetie, sweetie, Dave was talking." to David and Leonard.
# Penny says "You know, I love science." to David and Leonard.
# Leonard says "- Since when? " to David and Penny.
# Penny says "Call me a geek, but I am just nuts for the whole subatomic particle thing." to David and Leonard.
# David says "The last thing I would ever call you is a geek." to Leonard and Penny.
# --------------------
# Correct Output: 0

# %% [markdown]
# ## Sample Raw and Cleaned Formats:

# %%
filePath = "/content/info4940-sitcom/cleaned-data/S1/The Big Bang_S0101.json"
nSentenceContext = 3

with open(filePath, 'r') as file:
  data = json.load(file)
  data = [info for (_, info) in data.items()]

print(f"Example raw entry:")
display(data[3])

print(f"\n\nExample formatted entry ({nSentenceContext}context) (0-shot):\n")
input = transformInput(context=data[:3], target=data[3])
for i in input:
  print(f"Role: {i['role']} | Content:\n{i['content']}\n")

print(f'Actual: {("isHumor" in data[3])}')


print(f"\n\nExample formatted entry ({nSentenceContext}context) (4-shot):\n")
input = transformInput(context=data[:3], target=data[3])
input = addNShotText(input, nShotText)


for i in input:
  print(f"Role: {i['role']} | Content:\n{i['content']}\n")

print(f'Actual: {("isHumor" in data[3])}')
# Out:
# Example raw entry:
# {'EpisodeID': 'The Big Bang_S0101',
#  'Scene': 'A corridor at a sperm bank.',
#  'Recipients': ['Sheldon', 'Receptionist'],
#  'Speaker': 'Leonard',
#  'Dialogue': 'Excuse me.',
#  'Dialogue Start Time': '00:00:23:140000',
#  'Dialogue End Time': '00:00:25:060000'}
# Example formatted entry (3context) (0-shot):
#
# Role: system | Content:
# You are humor classification model, determine whether the target dialogue is humorous using the previous dialogue as context. RESTRICTION: ONLY RESPOND 1 (for humorous) OR 0 (for not humorous).
#
# Role: user | Content:
# Context:
# Sheldon says "So if a photon is directed through a plane with two slits in it and either slit is observed, it will not go through both slits. If it's unobserved, it will. However, if it's observed after it's left the plane but before it hits its target, it won't have gone through both slits." to Leonard.
# Leonard says "Agreed. What's your point?" to Sheldon.
# Sheldon says "There's no point, I just think it's a good idea for a T-shirt." to Leonard.
#
# Target:
# Leonard says "Excuse me." to Sheldon and Receptionist.
#
#
# Is the target dialogue humorous (return 1) or not humorous (return 0)?
#
# Actual: False
#
#
# Example formatted entry (3context) (4-shot):
#
# Role: system | Content:
# You are humor classification model, determine whether the target dialogue is humorous using the previous dialogue as context. RESTRICTION: ONLY RESPOND 1 (for humorous) OR 0 (for not humorous).
#
# Here are some examples of the task:
#
#
# Example 1:
# Target moment:
# The Scene is still: The university cafeteria. Raj has the cricket in a jar.
# Sheldon says "Hang on. Voil?. The snowy tree cricket. AKA Oecanthus fultoni, which is Latin for I'll suck nothing." to Raj and Howard.
# --------------------
# Context:
# The Scene is still: The university cafeteria. Raj has the cricket in a jar.
# Raj says "Ugh, Toby, what did you do in a past life to be so disgusting now?" to Sheldon.
# Sheldon says "His name isn't Toby Toby is an absurd name for a cricket." to Raj.
# Raj says "What would you name him?" to Sheldon.
# Sheldon says "An appropriate cricket name. For example, Jiminy." to Raj.
# Howard says "All right, Sheldon, here we go. Kleingast's Field Guide to North American Insects. Hey, Toby. Right here. See it? The common field cricket, AKA Gryllus assimilis, which is Latin for "suck it, you lose."" to Raj and Sheldon.
# --------------------
# Correct Output: 1
#
# Example 2:
# Target moment:
# The Scene is still: The apartment.
# Leonard says "I'm sorry about all of Sheldon's interruptions. He can be a bit of an eccentric." to Leslie.
# --------------------
# Context:
# The Scene is still: The apartment.
# Sheldon  says "Don't forget the male-pattern baldness." to Leslie, Leonard and Sheldon.
# Sheldon says "When his uncles sit around the dinner table, they look like a half carton of eggs." to Leslie and Leonard.
# Leonard says "Okay, my uncles are bald, but my Aunt Edna is one of the hairiest women you'll ever meet." to Leslie and Sheldon.
# Leonard says "Sweet lady. Always tickles when she hugs me." to Leslie and Sheldon.
# Leonard says "- What now? " to Leslie and Sheldon.
# --------------------
# Correct Output: 0
#
# Example 3:
# Target moment:
# The Scene is still: The apartment. Leonard and Leslie are kissing.
# Leonard says "Truth? What truth? We're talking about untested hypothes. It's no big deal." to Sheldon and Leslie.
# --------------------
# Context:
# The Scene is still: The apartment. Leonard and Leslie are kissing.
# Leonard says "Sheldon, don't make that noise. It's disrespectful." to Sheldon and Leslie.
# Sheldon says "I should hope so. It was a snort of derision." to Leonard and Leslie.
# Leslie says "You agree with me, right? Loop quantum gravity is the future of physics." to Sheldon and Leonard.
# Leonard says "Sorry, Leslie, I guess I prefer my space stringy, not loopy." to Sheldon and Leslie.
# Leslie says "I'm glad I found out the truth about you before this went any further." to Sheldon and Leonard.
# --------------------
# Correct Output: 0
#
# Example 4:
# Target moment:
# The Scene is still: The apartment. The guys are playing Wii bowling.
# Howard says "And that, Charlie Brown, is what boredom is all about." to Raj, Sheldon and Leonard.
# --------------------
# Context:
# The Scene is still: The apartment. The guys are playing Wii bowling.
# Howard says "Yeah. It's officially a bro-mance." to Raj, Sheldon and Leonard.
# Penny  says "Are you and Leonard putting up a Christmas tree?" to Raj, Sheldon, Howard and Leonard.
# Sheldon says "No, because we don't celebrate the ancient pagan festival of Saturnalia." to Raj, Howard and Leonard.
# Penny says "- Saturnalia? " to Raj, Sheldon, Howard and Leonard.
# Sheldon says "In the pre-Christian era, as the winter solstice approached and the plants died, pagans brought evergreen boughs into their homes as an act of sympathetic magic, intended to guard the life essences of the plants until spring. This custom was later appropriated by Northern Europeans and eventually it becomes the so-called Christmas tree." to Raj, Howard and Leonard.
# --------------------
# Correct Output: 1
#
# Example 5:
# Target moment:
# The Scene is still: The apartment.
# Penny  says "Okay, good night." to Leslie, Leonard, Eric and Penny.
# --------------------
# Context:
# The Scene is still: The apartment.
# Eric  says "From the Charlie Brown cartoons?" to Leslie, Leonard, Eric and Penny.
# Penny says "No, he was some kind of scientist. Let me start again. - Hey, Leonard. " to Leslie, Leonard and Eric.
# Leonard says "- Hello." to Leslie, Eric and Penny.
# Penny says "- Leslie. " to Leslie, Leonard and Eric.
# Leonard says "Okay, well... good night." to Leslie, Eric and Penny.
# --------------------
# Correct Output: 1
#
# Example 6:
# Target moment:
# The Scene is still:  The apartment.
# Howard says "No, no, not this time. I know insects, my friend. I spent many childhood years capturing them with nets, putting them in glass jars, sticking pins through them, mounting them on corrugated cardboard with Dymo labels underneath, identifying the genus and species. In Latin." to Raj and Sheldon.
# --------------------
# Context:
# The Scene is still:  The apartment.
# Sheldon says "In 1890, Emile Dolbear determined that there was a fixed relationship between the number of chirps per minute of the snowy tree cricket and the ambient temperature. A precise relationship that is not present with ordinary field crickets." to Raj and Howard.
# Raj says "How do you know what the exact temperature of the room is?" to Howard and Sheldon.
# Sheldon says "Under the terms of my roommate agreement with Leonard, I've had unilateral control of the thermostat ever since the sweaty night of '06." to Raj and Howard.
# Howard says "Okay, you were right about wolverine and bone claws, but you're wrong about the cricket." to Raj and Sheldon.
# Sheldon says "Howard, don't embarrass yourself. The science chirps for itself. (chuckling): Humorous word play." to Raj and Howard.
# --------------------
# Correct Output: 1
#
# Example 7:
# Target moment:
# The Scene is still: The Entomology Department.
# Howard says "Well, could you look at Toby?" to Raj, Sheldon and ProfCrawley.
# --------------------
# Context:
# The Scene is still: The Entomology Department.
# Prof Crawley says "What's your deal? Are they planning to outsource my job to Bangalore?" to Raj, Howard, Sheldon and ProfCrawley.
# Raj says "I'm from New Delhi." to Howard, Sheldon and ProfCrawley.
# Raj says "Maybe you should find another entomologist." to Howard, Sheldon and ProfCrawley.
# Sheldon says "No, no. We're here. Let's settle this. Professor, can you identify our cricket?" to Raj, Howard and ProfCrawley.
# Prof Crawley says "Of course I can. I can identify every insect and arachnid on the planet. Not that that's going to keep me from having to move in with my daughter in Oxnard. And we're not talking Oxnard at the beach. No! We're talking Oxnard in the onion fields." to Raj, Howard, Sheldon and ProfCrawley.
# --------------------
# Correct Output: 0
#
# Example 8:
# Target moment:
# The scene changes to: The university cafeteria.
# Sheldon says "You know how I know we're not in the matrix?" to Leonard.
# --------------------
# Context:
# The Scene is still: The university cafeteria.
# The scene changes to: The apartment.
# Howard says "Yeah, so? Be a tool." to Leonard, Raj and Sheldon.
# Howard says "Go get yourself a little rebound stress release." to Leonard, Raj and Sheldon.
# Raj says "Technically, it would only be rebound if he and Penny had actually engaged in physical intimacy." to Leonard, Howard and Sheldon.
# Howard says "Like you and Richard the slave girl?" to Leonard, Raj and Sheldon.
# Raj says "I bought him dinner and we kissed once! That was it. And he told me his name was Kimberly." to Leonard, Howard and Sheldon.
# --------------------
# Correct Output: 1
#
# Example 9:
# Target moment:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Raj says "By moving on, do you mean she's going out with other men and you spent the afternoon making 15th-century soap with Wolowitz?" to Sheldon, Leonard and Howard.
# --------------------
# Context:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Eric  says "I like your hat." to Sheldon, Leonard, Howard, Raj, Penny and Eric.
# Howard says "Thanks, my mom made it." to Sheldon, Leonard and Raj.
# Howard says "Penny with a new guy, très awkward." to Sheldon, Leonard and Raj.
# Leonard says "It wasn't awkward. It wasn't fun." to Sheldon, Howard and Raj.
# Leonard says "Besides, what's the big deal? We dated, we stopped dating, and now we're both moving on." to Sheldon, Howard and Raj.
# --------------------
# Correct Output: 1
#
# Example 10:
# Target moment:
# The Scene is still: The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.
# Leonard says "You know what I mean. Could you just give us a little privacy?" to Sheldon.
# --------------------
# Context:
# The Scene is still: The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.
# Leonard says "It's a date. I have a date coming over." to Sheldon.
# Sheldon says "You can't blame me for not jumping to that conclusion." to Leonard.
# Leonard says "Why? What's so unusual about me having a date?" to Sheldon.
# Leonard says "- All right, all right. Nevertheless, I have one now and I'd appreciate it if you would, make yourself scarce." to Sheldon.
# Sheldon says "I'm a published theoretical physicist with two doctorates and an IQ which can't be accurely measured by normal tests. How much scarcer could I be?" to Leonard.
# --------------------
# Correct Output: 0
#
# Example 11:
# Target moment:
# The Scene is still:  The apartment.
# Raj says ". Chickens can't climb trees" to Howard and Sheldon.
# --------------------
# Context:
# The Scene is still:  The apartment.
# Sheldon says "Thatis a snowy tree cricket. Oecanthus fultoni. I was done with Latin by fifth grade." to Raj and Howard.
# Howard says "Okay, okay, tell you what. I am willing to bet anything that's an ordinary field cricket." to Raj and Sheldon.
# Sheldon says "I can't take your money." to Raj and Howard.
# Howard says "What's the matter, you chicken?" to Raj and Sheldon.
# Sheldon says "I've always found that an inappropriate slur. Chickens are not, by nature, at all timid. In fact, when I was young, my neighbor's chicken got loose and chased me up the big elm tree in front of our house." to Raj and Howard.
# --------------------
# Correct Output: 0
#
# Example 12:
# Target moment:
# The Scene is still: The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.
# Penny says "Why are you doing it on the stairs?" to Sheldon.
# --------------------
# Context:
# The Scene is still: The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.
# The scene changes to: The apartment. Leonard is dressed smartly and placing wine on the table. Sheldon enters.
# Sheldon says "Why should I leave? This is my apartment, too." to Leonard.
# Leonard says "I know, and if science ever discovers a second member of your species and you two would like some privacy, I'd be more than happy to get out of your way." to Sheldon.
# Sheldon says "Well, all right then." to Leonard.
# The scene changes to: The entrance lobby. Sheldon is sitting on the bottom step using his laptop. Penny comes down the stairs.
# Penny says "What are you doing?" to Sheldon.
# Sheldon says "Playing Super Mario on a poorly coded Nintendo 64 emulator." to Penny.
# --------------------
# Correct Output: 0
#
# Example 13:
# Target moment:
# The Scene is still:  The apartment.
# Sheldon says "Now I can eat." to Raj and Howard.
# --------------------
# Context:
# The Scene is still:  The apartment.
# Leonard says "Actually, ethyl alcohol inhibits electrical conduction in the nerve cells and stimulates reuptake receptors of inhibitory neurotransmitters like gamma-aminobutyric acid." to Penny.
# Penny says "Don't talk, just drink." to Leonard.
# Howard says "No, you're misunderstanding A shiksa goddess isn't an actual goddess And we don't pray to them. We prey on them." to Raj and Sheldon.
# Raj says "Whatever, dude. The point is, Leonard's got one and you don't." to Howard and Sheldon.
# Sheldon says "Is this it? It was inappropriate to discuss Leonard and Penny's sex life in front of Leonard and Penny. Oh, good!" to Raj and Howard.
# --------------------
# Correct Output: 1
#
# Example 14:
# Target moment:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Penny says "It's good to see you, too." to Sheldon, Leonard, Howard, Raj and Eric.
# --------------------
# Context:
# The Scene is still: The building entrance lobby. The guys enter. Sheldon is dressed as a medieval monk, Howard is a court jester, Raj is a medieval gentleman and Leonard is a knight.
# Penny  says "Hi, guys." to Sheldon, Leonard, Howard, Raj, Penny and Eric.
# Penny says "Looks like you've been to the renaissance fair... I'm hoping." to Sheldon, Leonard, Howard, Raj and Eric.
# Sheldon says "Renaissance fair? More of a medieval, slash, Age of Enlightenment, slash, any-excuse-to-wear-a-codpiece fair." to Leonard, Howard, Raj, Penny and Eric.
# Penny says "Okay, fine, whatever. This is my friend Eric." to Sheldon, Leonard, Howard, Raj and Eric.
# Leonard says "- Hey. So, yeah, good to see you." to Sheldon, Howard, Raj, Penny and Eric.
# --------------------
# Correct Output: 1
#
# Example 15:
# Target moment:
# The Scene is still: The apartment
# Sheldon says "Have I crossed some sort of line again?" to Leonard.
# --------------------
# Context:
# The Scene is still: The apartment
# Leonard says "Right, right. You're saying you talked to Penny?" to Sheldon.
# Sheldon says "Ye-Yes." to Leonard.
# Leonard says "Interesting." to Sheldon.
# Sheldon says "Hardly." to Leonard.
# Leonard says "Excuse me." to Sheldon.
# --------------------
# Correct Output: 0
#
# Example 16:
# Target moment:
# The Scene is still: The stairwell.
# Penny says "Well, that's what I am... queen of the nerds." to David and Leonard.
# --------------------
# Context:
# The Scene is still: The stairwell.
# Penny says "Sweetie, sweetie, Dave was talking." to David and Leonard.
# Penny says "You know, I love science." to David and Leonard.
# Leonard says "- Since when? " to David and Penny.
# Penny says "Call me a geek, but I am just nuts for the whole subatomic particle thing." to David and Leonard.
# David says "The last thing I would ever call you is a geek." to Leonard and Penny.
# --------------------
# Correct Output: 0
#
# Role: user | Content:
# Context:
# Sheldon says "So if a photon is directed through a plane with two slits in it and either slit is observed, it will not go through both slits. If it's unobserved, it will. However, if it's observed after it's left the plane but before it hits its target, it won't have gone through both slits." to Leonard.
# Leonard says "Agreed. What's your point?" to Sheldon.
# Sheldon says "There's no point, I just think it's a good idea for a T-shirt." to Leonard.
#
# Target:
# Leonard says "Excuse me." to Sheldon and Receptionist.
#
#
# Is the target dialogue humorous (return 1) or not humorous (return 0)?
#
# Actual: False

# %% [markdown]
# # The LLAMA 3 8B instruct model

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.1

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

# %%
model_id = "meta-llama/Meta-Llama-3-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id,
                                          token=userdata.get('HF_TOKEN'),
                                          low_cpu_mem_usage=True,
                                          quantization_config=quantization_config,
                                          )

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    token=userdata.get('HF_TOKEN')
)

# %%
# Saves Model to Drive

model_path = '/content/drive/My Drive/INFO4940_humor/LLAMA3_8b_instruct_Quantized_4bit'

model.save_pretrained(model_path)

# %%
# Loads Model from Drive

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)
model_id = "meta-llama/Meta-Llama-3-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_id,
                                          token=userdata.get('HF_TOKEN'),
                                          low_cpu_mem_usage=True,
                                          quantization_config=quantization_config,
                                          )

model_path = '/content/drive/My Drive/INFO4940_humor/LLAMA3_8b_instruct_Quantized_4bit'
model = AutoModelForCausalLM.from_pretrained(model_path)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# # Testing

# %%
terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|eot_id|>")
]


input = inputs[0]
label = labels[0]

input_ids = tokenizer.apply_chat_template(
  input,
  add_generation_prompt=True,
  return_tensors="pt"
).to(model.device)

outputs = model.generate(
  input_ids,
  max_new_tokens=50,
  eos_token_id=terminators,
  do_sample=True,
  temperature=0.5,
  top_p=0.9,
  num_return_sequences=1,
)

response = outputs[0][input_ids.shape[-1]:]
response = tokenizer.decode(response, skip_special_tokens=True)

print(response)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 1

# %%
print(tokenizer.decode(input_ids[0], skip_special_tokens=False))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# You are humor classification model, determine whether the target dialogue is humorous using the previous dialogue as context. RESTRICTION: ONLY RESPOND 1 (for humorous) OR 0 (for not humorous).<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Context:
# Bernadette says "Actually, I think a lot of them are Jewish." to Howard.
# Howard says "No, I was just... Never mind." to Bernadette.
# Bernadette says "Look, Howard, this is our third date and we both know what that means." to Howard.
# Howard says "- We do? " to Bernadette.
# Howard says "You're kidding." to Bernadette.
#
# Target:
# Bernadette says "But I need to know whether you're looking for a relationship or a one-night stand." to Howard.
#
#
# Is the target dialogue humorous (return 1) or not humorous (return 0)?<|eot_id|><|start_header_id|>assistant<|end_header_id|>

# %%
print(input)
print(f'expected: {label}, model: {response}')


for i in input:
  print(i['content'])
# Out:
# [{'role': 'system', 'content': 'You are humor classification model, determine whether the target dialogue is humorous using the previous dialogue as context. RESTRICTION: ONLY RESPOND 1 (for humorous) OR 0 (for not humorous).'}, {'role': 'user', 'content': 'Context:\nBernadette says "Actually, I think a lot of them are Jewish." to Howard.\nHoward says "No, I was just... Never mind." to Bernadette.\nBernadette says "Look, Howard, this is our third date and we both know what that means." to Howard.\nHoward says "- We do? " to Bernadette.\nHoward says "You\'re kidding." to Bernadette.\n\nTarget:\nBernadette says "But I need to know whether you\'re looking for a relationship or a one-night stand." to Howard.\n\n\nIs the target dialogue humorous (return 1) or not humorous (return 0)?'}]
# expected: 0, model: 1
# You are humor classification model, determine whether the target dialogue is humorous using the previous dialogue as context. RESTRICTION: ONLY RESPOND 1 (for humorous) OR 0 (for not humorous).
# Context:
# Bernadette says "Actually, I think a lot of them are Jewish." to Howard.
# Howard says "No, I was just... Never mind." to Bernadette.
# Bernadette says "Look, Howard, this is our third date and we both know what that means." to Howard.
# Howard says "- We do? " to Bernadette.
# Howard says "You're kidding." to Bernadette.
#
# Target:
# Bernadette says "But I need to know whether you're looking for a relationship or a one-night stand." to Howard.
#
#
# Is the target dialogue humorous (return 1) or not humorous (return 0)?

# %%
results, resultsData, pred, report = testLLAMA(inputs, labels, printResultsEveryN=10)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 1 of  500
# Success rate: 0.00%
#
# results data: {'truePos': 0, 'trueNeg': 0, 'falsePos': 1, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 11 of  500
# Success rate: 63.64%
#
# results data: {'truePos': 7, 'trueNeg': 0, 'falsePos': 4, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 21 of  500
# Success rate: 47.62%
#
# results data: {'truePos': 10, 'trueNeg': 0, 'falsePos': 11, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 31 of  500
# Success rate: 54.84%
#
# results data: {'truePos': 16, 'trueNeg': 1, 'falsePos': 14, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 41 of  500
# Success rate: 51.22%
#
# results data: {'truePos': 19, 'trueNeg': 2, 'falsePos': 20, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 51 of  500
# Success rate: 52.94%
#
# results data: {'truePos': 24, 'trueNeg': 3, 'falsePos': 24, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 61 of  500
# Success rate: 52.46%
#
# results data: {'truePos': 29, 'trueNeg': 3, 'falsePos': 29, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 71 of  500
# Success rate: 53.52%
#
# results data: {'truePos': 35, 'trueNeg': 3, 'falsePos': 33, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 81 of  500
# Success rate: 56.79%
#
# results data: {'truePos': 43, 'trueNeg': 3, 'falsePos': 35, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 91 of  500
# Success rate: 57.14%
#
# results data: {'truePos': 49, 'trueNeg': 3, 'falsePos': 39, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 101 of  500
# Success rate: 55.45%
#
# results data: {'truePos': 53, 'trueNeg': 3, 'falsePos': 45, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 111 of  500
# Success rate: 56.76%
#
# results data: {'truePos': 60, 'trueNeg': 3, 'falsePos': 48, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 121 of  500
# Success rate: 57.02%
#
# results data: {'truePos': 66, 'trueNeg': 3, 'falsePos': 52, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 131 of  500
# Success rate: 58.02%
#
# results data: {'truePos': 73, 'trueNeg': 3, 'falsePos': 55, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 141 of  500
# Success rate: 56.74%
#
# results data: {'truePos': 77, 'trueNeg': 3, 'falsePos': 61, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 151 of  500
# Success rate: 56.29%
#
# results data: {'truePos': 82, 'trueNeg': 3, 'falsePos': 66, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 161 of  500
# Success rate: 54.66%
#
# results data: {'truePos': 85, 'trueNeg': 3, 'falsePos': 73, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 171 of  500
# Success rate: 53.80%
#
# results data: {'truePos': 88, 'trueNeg': 4, 'falsePos': 79, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 181 of  500
# Success rate: 52.49%
#
# ...
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 441 of  500
# Success rate: 52.38%
#
# results data: {'truePos': 218, 'trueNeg': 13, 'falsePos': 207, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 451 of  500
# Success rate: 52.33%
#
# results data: {'truePos': 223, 'trueNeg': 13, 'falsePos': 212, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 461 of  500
# Success rate: 52.28%
#
# results data: {'truePos': 227, 'trueNeg': 14, 'falsePos': 217, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 471 of  500
# Success rate: 52.65%
#
# results data: {'truePos': 234, 'trueNeg': 14, 'falsePos': 219, 'falseNeg': 4}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 481 of  500
# Success rate: 52.39%
#
# results data: {'truePos': 238, 'trueNeg': 14, 'falsePos': 225, 'falseNeg': 4}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 491 of  500
# Success rate: 52.14%
#
# results data: {'truePos': 240, 'trueNeg': 16, 'falsePos': 231, 'falseNeg': 4}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Final success rate: 52.40%

# %%
true = [str(i) for i in labels]
report = classification_report(y_pred=pred, y_true=true, target_names=["Non-Humorous","Humorous"])

# %%
print(resultsData['falsePos'][0]['input'])
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# You are humor classification model, determine whether the target dialogue is humorous using the previous dialogue as context. RESTRICTION: ONLY RESPOND 1 (for humorous) OR 0 (for not humorous).<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Context:
# Bernadette says "Actually, I think a lot of them are Jewish." to Howard.
# Howard says "No, I was just... Never mind." to Bernadette.
# Bernadette says "Look, Howard, this is our third date and we both know what that means." to Howard.
# Howard says "- We do? " to Bernadette.
# Howard says "You're kidding." to Bernadette.
#
# Target:
# Bernadette says "But I need to know whether you're looking for a relationship or a one-night stand." to Howard.
#
#
# Is the target dialogue humorous (return 1) or not humorous (return 0)?<|eot_id|><|start_header_id|>assistant<|end_header_id|>

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
# Non-Humorous       0.80      0.06      0.12       250
#     Humorous       0.51      0.98      0.67       250
#
#     accuracy                           0.52       500
#    macro avg       0.66      0.52      0.40       500
# weighted avg       0.66      0.52      0.40       500

# %% [markdown]
# # Some interesting outputs along the way:
#
# ## user: "**What do you know about the sitcom the Big Bang Theory?**"
#
# A popular and iconic sitcom! The Big Bang Theory is a American sitcom that originally aired from 2007 to 2019. Created by Chuck Lorre and Bill Prady, the show is a comedy about a group of socially awkward and intellectually brilliant scientists and their neighbor, a waitress and aspiring actress.
#
# The show revolves around the lives of five main characters:
#
# 1. Sheldon Cooper (played by Jim Parsons), a theoretical physicist with Asperger's syndrome and a strict adherence to routine.
# 2. Leonard Hofstadter (played by Johnny Galecki), an experimental physicist and Sheldon's roommate and best friend.
# 3. Howard Wolowitz (played by Simon Helberg), an aerospace engineer and fellow physicist who lives across the hall from Leonard and Sheldon.
# 4. Rajesh "Raj" Koothrappali (played by Kunal Nayyar), an astrophysicist who is unable to speak in the presence of women unless he drinks alcohol.
# 5. Penny (played by Kaley Cuoco), a waitress and aspiring actress who lives across the hall from Leonard and Sheldon.
#
# Throughout the show's 12 seasons, the characters navigate their personal and professional lives, often finding themselves in humorous and absurd situations. The show explores themes such as friendship, love, and the [cut off]
#
# -------------------
#
# ## Prompt:
# system: "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."
#
# user: 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond '1' for humorous or '0' for not humorous:
#
# The Scene is still: The Cafeteria
# Sheldon says "It's not what it looks like." to Leonard.'
#
# assistant: 'Can you provide some context to help me with this decision?'
#
# user: 'Yes, use the following as context:
#
# The Scene is still: The Cafeteria
# Priya says "My brother-- he's got a big crush on Bernadette." to Leonard.
# Leonard says "You're moving back to India?" to Priya.
# Leonard says "What's going on?" to Raj, Penny, Raj and Howard.
# Penny says "It's-It's not what it looks like." to Raj, Leonard, Raj and Howard.Sheldon says "What does it look like?" to Raj, Leonard, Raj and Howard.
#
#
# ## Model's Response:
#
# Based on the context, I would classify the target moment as humorous. The phrase "It's not what it looks like" is a common idiomatic expression, but in this scene, it's being used in a way that's reminiscent of a soap opera or a melodrama, which adds a layer of humor to the situation. The fact that Sheldon is asking "What does it look like?" also implies that he's being obtuse and unaware of the obvious, which is a characteristic that's often played for comedic effect in the show.
