# %% [markdown]
# <a href="https://colab.research.google.com/github/adc257/info4940-sitcom/blob/main/10nContext_LLAMA_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.29.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
from google.colab import userdata
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import random
import json
import os

# %%
# !git clone https://github.com/adc257/info4940-sitcom.git
# Out:
# Cloning into 'info4940-sitcom'...
# remote: Enumerating objects: 1113, done.
# remote: Counting objects: 100% (1113/1113), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 1113 (delta 966), reused 1046 (delta 917), pack-reused 0
# Receiving objects: 100% (1113/1113), 14.70 MiB | 6.79 MiB/s, done.
# Resolving deltas: 100% (966/966), done.

# %% [markdown]
# # Defining some helper functions

# %%
def list_files(start_path):
    file_paths = []
    for root, dirs, files in os.walk(start_path):
        for file in files:
            file_paths.append(os.path.join(root, file))

    file_paths.sort()
    return file_paths

def fPathList_TO_DialogueWithContext(filePathList, nSentenceContext):
  humorous_inputs = []
  non_humorous_inputs = []

  # formatted_inputs = []
  # labels = []

  for episodePath in filePathList:

    with open(episodePath, 'r') as file:
      data = json.load(file)
      data = [info for (_, info) in data.items()]


      i = nSentenceContext
      while i < len(data):
        context = [data[j] for j in range(i-nSentenceContext, i)]
        target = data[i]

        if 'isHumor' in target:
          humorous_inputs.append(transformInput(context, target))
        else:
          non_humorous_inputs.append(transformInput(context, target))

        i += 1

  return humorous_inputs, non_humorous_inputs

def sampleEven(humorousData, nonHumorousData, sample_size_per_class, rand_seed):
  sample_size_per_class = min(sample_size_per_class, len(humorousData), len(nonHumorousData))

  sample_inputs = []
  sample_labels = []

  data = humorousData
  test_size = (len(data) - sample_size_per_class) / len(data)
  sample, _ = train_test_split(data, test_size=test_size, random_state=rand_seed)
  sample_inputs += sample
  sample_labels += [1]*len(sample)


  data = nonHumorousData
  test_size = (len(data) - sample_size_per_class) / len(data)
  sample, _ = train_test_split(data, test_size=test_size, random_state=rand_seed)
  sample_inputs += sample
  sample_labels += [0]*len(sample)

  return sample_inputs, sample_labels
def testLLAMA(inputs, labels, printResultsEveryN=50):
  resultsData = {
      "truePos": [],
      "trueNeg": [],
      "falsePos": [],
      "falseNeg": [],
  }

  results = {
      "truePos": 0,
      "trueNeg": 0,
      "falsePos": 0,
      "falseNeg": 0,
  }

  correct = 0
  total = 0
  pred = []

  terminators = [
      tokenizer.eos_token_id,
      tokenizer.convert_tokens_to_ids("<|eot_id|>")
  ]

  for i in range(len(inputs)):
    input = inputs[i]
    label = labels[i]

    input_ids = tokenizer.apply_chat_template(
      input,
      add_generation_prompt=True,
      return_tensors="pt"
    ).to(model.device)

    outputs = model.generate(
      input_ids,
      max_new_tokens=50,
      eos_token_id=terminators,
      do_sample=True,
      temperature=0.6,
      top_p=0.9,
      num_return_sequences=1,
    )

    response = outputs[0][input_ids.shape[-1]:]
    response = tokenizer.decode(response, skip_special_tokens=True)

    resultsDict = {
        "input": input,
        "output": response,
    }


    if str(response) == str(label):
      # true
      if str(label) == "1":
        # pos
        resultsData["truePos"].append(resultsDict)
        results["truePos"] += 1
      else:
        # neg
        resultsData["trueNeg"].append(resultsDict)
        results["trueNeg"] += 1
      correct += 1
    else:
      # false
      if str(label) == "1":
        # pos, pred neg
        resultsData["falseNeg"].append(resultsDict)
        results["falseNeg"] += 1
      else:
        # neg, pred pos
        resultsData["falsePos"].append(resultsDict)
        results["falsePos"] += 1
    pred.append(response)
    total += 1

    if i % printResultsEveryN == 0:
      print(f"Test: {i+1} of  {len(inputs)}")
      print(f"Success rate: {correct / total:.2%}\n")

      print(f"Results summary: {results}\n")


  print(f"Final success rate: {correct / total:.2%}")

  # true = [str(i) for i in labels]
  # report = classification_report(y_pred=pred, y_true=true, target_names=["Non-Humorous","Humorous"])
  report = None

  return results, resultsData, pred, report

# %% [markdown]
# ## Defining input formatter

# %%
def transformInput(context, target):
  messages = []

  separator = "\n"
  quotation_token = '"'

  # formatted_input = ""

  systemPrmpt = {
      'role': 'system',
      'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."
  }
  # append systemPrmpt
  messages.append(systemPrmpt)

  systemPrmpt2 = {
      'role': 'system',
      'content': ""
  }
  userPrmpt = {
      'role': 'user',
      'content': ""
  }
  userPrmpt2 = {
      'role': 'user',
      'content': ""
  }
  asstPrmpt = {
      'role': 'assistant',
      'content': ""
  }

  current_scene = context[0]['Scene']

  userPrmpt['content'] += "Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond '1' for humorous or '0' for not humorous:"
  userPrmpt['content'] += separator*2
  entry = target
  if entry['Scene'] != current_scene:
    current_scene = entry["Scene"]
    userPrmpt['content'] += "The scene changes to: "
  else:
    userPrmpt['content'] += "The Scene is still: "

  userPrmpt['content'] += current_scene + separator


  recipients = entry['Recipients']
  recipients_str = ""
  if len(recipients) == 0:
    recipients_str += "to themselves"
  elif len(recipients) == 1:
    recipients_str += recipients[0]
  else:
    recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

  userPrmpt['content'] += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}."

  # append userPrmpt
  messages.append(userPrmpt)

  asstPrmpt['content'] += "Can you provide some context to help me with this decision?"
  # append asstPrmpt
  messages.append(asstPrmpt)

  userPrmpt2['content'] += "Yes, use the following as context:" + separator*2

  if entry['Scene'] != current_scene:
    current_scene = entry["Scene"]
    userPrmpt2['content'] += "The scene changes to: "
  else:
    userPrmpt2['content'] += "The Scene is still: "

  userPrmpt2['content'] += current_scene + separator

  for entry in context:
    if current_scene != entry['Scene']:
      current_scene = entry["Scene"]
      userPrmpt2['content'] += "The scene changes to: " + current_scene + separator

    recipients = entry['Recipients']
    recipients_str = ""
    if len(recipients) == 0:
      recipients_str += "to themselves"
    elif len(recipients) == 1:
      recipients_str += recipients[0]
    else:
      recipients_str += ", ".join(recipients[:-1]) + " and " + recipients[-1]

    userPrmpt2['content'] += f"{entry['Speaker']} says {quotation_token}{entry['Dialogue']}{quotation_token} to {recipients_str}."
    userPrmpt2['content'] += separator

  # append userPrmpt2
  messages.append(userPrmpt2)

  # userPrmpt2['content'] += separator + "-" *20 + separator*2

  # systemPrmpt2['content'] += "Using the context provided, return '1' if the target_moment was humorous or '0' if the target_moment was not humorous?"

  # append systemPrmpt2
  # messages.append(systemPrmpt2)

  # messages = [systemPrmpt, userPrmpt, asstPrmpt, ]

  return messages

# %% [markdown]
# ### Sample Raw and Cleaned Formats:

# %%
filePath = "/content/info4940-sitcom/cleaned-data/S1/The Big Bang_S0101.json"
nSentenceContext = 5

with open(filePath, 'r') as file:
  data = json.load(file)
  data = [info for (_, info) in data.items()]

print(f"Example raw entry:")
display(data[3])

print(f"\n\nExample formatted entry ({nSentenceContext}context):\n")
input = transformInput(data[:3], data[3])

for i in input:
  print(f"Role: {i['role']} | Content:\n{i['content']}\n")

print(f'Actual: {("isHumor" in data[3])}')
# Out:
# Example raw entry:
# {'EpisodeID': 'The Big Bang_S0101',
#  'Scene': 'A corridor at a sperm bank.',
#  'Recipients': ['Sheldon', 'Receptionist'],
#  'Speaker': 'Leonard',
#  'Dialogue': 'Excuse me.',
#  'Dialogue Start Time': '00:00:23:140000',
#  'Dialogue End Time': '00:00:25:060000'}
# Example formatted entry (5context):
#
# Role: system | Content:
# You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0.
#
# Role: user | Content:
# Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond '1' for humorous or '0' for not humorous:
#
# The Scene is still: A corridor at a sperm bank.
# Leonard says "Excuse me." to Sheldon and Receptionist.
#
# Role: assistant | Content:
# Can you provide some context to help me with this decision?
#
# Role: user | Content:
# Yes, use the following as context:
#
# The Scene is still: A corridor at a sperm bank.
# Sheldon says "So if a photon is directed through a plane with two slits in it and either slit is observed, it will not go through both slits. If it's unobserved, it will. However, if it's observed after it's left the plane but before it hits its target, it won't have gone through both slits." to Leonard.
# Leonard says "Agreed. What's your point?" to Sheldon.
# Sheldon says "There's no point, I just think it's a good idea for a T-shirt." to Leonard.
#
#
# Actual: False

# %% [markdown]
# # Creating sample data

# %%
filePaths = []
for i in range(5):
  fPath = '/content/info4940-sitcom/cleaned-data/S' + str(i+1)
  filePaths += list_files(fPath)

# getting random number for random state for consistency?
rand_seed1 = 64 # random.randint(1,100)
rand_seed2 = 94 # random.randint(1,100)
rand_seed3 = 69 # random.randint(1,100)

# print([rand_seed1,rand_seed2,rand_seed3])

# sampling 10 episodes
nSamples = 10
test_size = (len(filePaths) - nSamples) / len(filePaths)
samplePaths, _ = train_test_split(filePaths, test_size=test_size, random_state=rand_seed1)

# cleaning/transforming inputs
nContext = 10
humorousData, nonHumorousData = fPathList_TO_DialogueWithContext(samplePaths, nContext)
sample_inputs, sample_labels = sampleEven(humorousData=humorousData, nonHumorousData=nonHumorousData, sample_size_per_class=250, rand_seed=rand_seed2)

# shuffling, not necessary but helpful for watching in-progress results
rand_order = [i for i in range(len(sample_inputs))]
random.seed(rand_seed3)
random.shuffle(rand_order)

inputs = [sample_inputs[i] for i in rand_order]
labels = [sample_labels[i] for i in rand_order]

# %% [markdown]
# # The LLAMA 3 8B instruct model

# %%
model_id = "meta-llama/Meta-Llama-3-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=userdata.get('HF_TOKEN'))
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    token=userdata.get('HF_TOKEN')
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu.

# %% [markdown]
# # Testing

# %%
terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|eot_id|>")
]


input = inputs[0]
label = labels[0]

input_ids = tokenizer.apply_chat_template(
  input,
  add_generation_prompt=True,
  return_tensors="pt"
).to(model.device)

outputs = model.generate(
  input_ids,
  max_new_tokens=50,
  eos_token_id=terminators,
  do_sample=True,
  temperature=0.3,
  top_p=0.9,
  num_return_sequences=1,
)

response = outputs[0][input_ids.shape[-1]:]
response = tokenizer.decode(response, skip_special_tokens=True)

print(response)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 1

# %%
print(input)
print(f'expected: {label}, model: {response}')
# Out:
# [{'role': 'system', 'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."}, {'role': 'user', 'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The cafeteria.\nHoward says "Well, Raj, I just want to say that I\'d never betray your trust. Unlike Leonard, I respect you." to Sheldon, Leonard and Raj.'}, {'role': 'assistant', 'content': 'Can you provide some context to help me with this decision?'}, {'role': 'user', 'content': 'Yes, use the following as context:\n\nThe Scene is still: The cafeteria.\nLeonard says "Yeah" to Sheldon, Raj and Howard.\nHoward says "How could you? We had a pact." to Sheldon, Leonard and Raj.\nRaj says "Excuse me, I think How could you? She\'s my sister takes precedence over a five-year-old pinky swear." to Sheldon, Leonard and Howard.\nSheldon says "May I point out, in a parallel universe, your friends are saying Maggie McGarry-- she sounds lovely." to Leonard, Raj and Howard.\nLeonard says "Look, I-I admit it, I may have crossed a line here, but come on, Raj, your sister is a grown woman, and to her, I\'m a forbidden piece of white chocolate." to Sheldon, Raj and Howard.\nRaj says "KOOTHRAPPALI: I don\'t believe it. This is a terrible betrayal of my trust." to Sheldon, Leonard and Howard.\nLeonard says "No, w-w-would it help if I told you that I offered her my heart, and she kind of stomped on it?" to Sheldon, Raj and Howard.\nRaj says "How hard did she stomp?" to Sheldon, Leonard and Howard.\nLeonard says "Very hard." to Sheldon, Raj and Howard.\nRaj says "Okay, I\'m good." to Sheldon, Leonard and Howard.\n'}]
# expected: 0, model: 1

# %%
print(input[3]['content'])
# Out:
# Yes, use the following as context:
#
# The Scene is still: The cafeteria.
# Leonard says "Yeah" to Sheldon, Raj and Howard.
# Howard says "How could you? We had a pact." to Sheldon, Leonard and Raj.
# Raj says "Excuse me, I think How could you? She's my sister takes precedence over a five-year-old pinky swear." to Sheldon, Leonard and Howard.
# Sheldon says "May I point out, in a parallel universe, your friends are saying Maggie McGarry-- she sounds lovely." to Leonard, Raj and Howard.
# Leonard says "Look, I-I admit it, I may have crossed a line here, but come on, Raj, your sister is a grown woman, and to her, I'm a forbidden piece of white chocolate." to Sheldon, Raj and Howard.
# Raj says "KOOTHRAPPALI: I don't believe it. This is a terrible betrayal of my trust." to Sheldon, Leonard and Howard.
# Leonard says "No, w-w-would it help if I told you that I offered her my heart, and she kind of stomped on it?" to Sheldon, Raj and Howard.
# Raj says "How hard did she stomp?" to Sheldon, Leonard and Howard.
# Leonard says "Very hard." to Sheldon, Raj and Howard.
# Raj says "Okay, I'm good." to Sheldon, Leonard and Howard.

# %%
results, resultsData, pred, report = testLLAMA(inputs, labels, printResultsEveryN=10)

true = [str(i) for i in labels]
report = classification_report(y_pred=pred, y_true=true, target_names=["Non-Humorous","Humorous"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 1 of  500
# Success rate: 0.00%
#
# Results summary: {'truePos': 0, 'trueNeg': 0, 'falsePos': 1, 'falseNeg': 0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 11 of  500
# Success rate: 63.64%
#
# Results summary: {'truePos': 6, 'trueNeg': 1, 'falsePos': 3, 'falseNeg': 1}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 21 of  500
# Success rate: 47.62%
#
# Results summary: {'truePos': 9, 'trueNeg': 1, 'falsePos': 10, 'falseNeg': 1}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 31 of  500
# Success rate: 54.84%
#
# Results summary: {'truePos': 14, 'trueNeg': 3, 'falsePos': 12, 'falseNeg': 2}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 41 of  500
# Success rate: 48.78%
#
# Results summary: {'truePos': 17, 'trueNeg': 3, 'falsePos': 19, 'falseNeg': 2}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 51 of  500
# Success rate: 49.02%
#
# Results summary: {'truePos': 22, 'trueNeg': 3, 'falsePos': 24, 'falseNeg': 2}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 61 of  500
# Success rate: 50.82%
#
# Results summary: {'truePos': 26, 'trueNeg': 5, 'falsePos': 27, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 71 of  500
# Success rate: 52.11%
#
# Results summary: {'truePos': 32, 'trueNeg': 5, 'falsePos': 31, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 81 of  500
# Success rate: 55.56%
#
# Results summary: {'truePos': 40, 'trueNeg': 5, 'falsePos': 33, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 91 of  500
# Success rate: 57.14%
#
# Results summary: {'truePos': 46, 'trueNeg': 6, 'falsePos': 36, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 101 of  500
# Success rate: 56.44%
#
# Results summary: {'truePos': 50, 'trueNeg': 7, 'falsePos': 41, 'falseNeg': 3}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 111 of  500
# Success rate: 56.76%
#
# Results summary: {'truePos': 56, 'trueNeg': 7, 'falsePos': 44, 'falseNeg': 4}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 121 of  500
# Success rate: 57.85%
#
# Results summary: {'truePos': 62, 'trueNeg': 8, 'falsePos': 47, 'falseNeg': 4}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 131 of  500
# Success rate: 58.02%
#
# Results summary: {'truePos': 68, 'trueNeg': 8, 'falsePos': 50, 'falseNeg': 5}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 141 of  500
# Success rate: 58.16%
#
# Results summary: {'truePos': 72, 'trueNeg': 10, 'falsePos': 54, 'falseNeg': 5}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 151 of  500
# Success rate: 58.94%
#
# Results summary: {'truePos': 77, 'trueNeg': 12, 'falsePos': 57, 'falseNeg': 5}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 161 of  500
# Success rate: 57.76%
#
# Results summary: {'truePos': 80, 'trueNeg': 13, 'falsePos': 63, 'falseNeg': 5}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 171 of  500
# Success rate: 56.14%
#
# Results summary: {'truePos': 82, 'trueNeg': 14, 'falsePos': 69, 'falseNeg': 6}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 181 of  500
# ...
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 441 of  500
# Success rate: 56.46%
#
# Results summary: {'truePos': 208, 'trueNeg': 41, 'falsePos': 179, 'falseNeg': 13}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 451 of  500
# Success rate: 56.32%
#
# Results summary: {'truePos': 213, 'trueNeg': 41, 'falsePos': 184, 'falseNeg': 13}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 461 of  500
# Success rate: 55.97%
#
# Results summary: {'truePos': 216, 'trueNeg': 42, 'falsePos': 189, 'falseNeg': 14}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 471 of  500
# Success rate: 56.48%
#
# Results summary: {'truePos': 224, 'trueNeg': 42, 'falsePos': 191, 'falseNeg': 14}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 481 of  500
# Success rate: 56.55%
#
# Results summary: {'truePos': 228, 'trueNeg': 44, 'falsePos': 195, 'falseNeg': 14}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Test: 491 of  500
# Success rate: 56.42%
#
# Results summary: {'truePos': 230, 'trueNeg': 47, 'falsePos': 200, 'falseNeg': 14}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Final success rate: 56.80%

# %%
print(report)
print(results)
# Out:
#               precision    recall  f1-score   support
#
# Non-Humorous       0.77      0.19      0.31       250
#     Humorous       0.54      0.94      0.69       250
#
#     accuracy                           0.57       500
#    macro avg       0.66      0.57      0.50       500
# weighted avg       0.66      0.57      0.50       500
#
# {'truePos': 236, 'trueNeg': 48, 'falsePos': 202, 'falseNeg': 14}

# %%
display(resultsData['trueNeg'])
# Out:
# [{'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The cafeteria.\nSheldon says "Who was at the door?" to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The cafeteria.\nLeonard says "Give me a minute. Sheldon." to Priya and Sheldon.\nSheldon says "Hold on. Trying to figure out how to get the bucket, so I can carry the mud past the dragon." to Leonard.\nLeonard says "Sheldon, you need to work in the morning." to Sheldon.\nSheldon says "I know!" to Leonard.\nLeonard says "Well, then bed, mister!" to Sheldon.\nSheldon says "Five more minutes!" to Leonard.\nLeonard says "Really? You\'re going to risk getting sleepy in the middle of your thermodynamic fluctuations seminar? You know what happens when you yawn in public." to Sheldon.\nSheldon says "Everyone will see my oddly shaped uvula." to Leonard.\nLeonard says "You don\'t want that, do you?" to Sheldon.\nSheldon says "No. But it\'s a shame our society mocks the differently uvulated." to Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The apartment. Leonard is on skype.\nLeonard says "Uh, not so good. We have to talk." to Priya.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The apartment. Leonard is on skype.\nThe scene changes to: Alice’s apartment. Alice and Leonard are kissing\nLeonard says "You\'re cool with you and me just being friends, right?" to Alice.\nAlice says "I don\'t believe this." to Leonard.\nLeonard says "Wait, I don\'t... Which part?" to Alice.\nAlice says "I\'m so stupid. I thought for once I\'d met a good guy, but you\'re just another jackass." to Leonard.\nLeonard says "Oh, no, no, you have it wrong. No. I-I was going to be a jackass, but I stopped myself." to Alice.\nLeonard says "I stayed a good guy, so... I\'m gonna pass on the sex. But you should know, that\'s not a comment on your hotness but on my goodness." to Alice.\nLeonard says "That\'s kind of my superpower. I\'m, like, Captain Good Guy." to Alice.\nThe scene changes to: Leonard being ejected into the corridor.\nLeonard says "It\'s okay. Did the right thing. You idiot!" to to themselves.\nThe scene changes to: The apartment. Leonard is on skype.\nLeonard says "Hey, Priya." to Priya.\nPriya says "Hey, sweetheart. How\'s it going?" to Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The International Space Station.\nHouston says "I.S.S., I\'m afraid we can\'t authorize that." to Voice and IISVoice.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The International Space Station.\nThe scene changes to: The apartment. Howard is on the phone.\nPenny says "Yeah, I said Leonard." to Howard, Raj, Sheldon and Leonard.\nLeonard says "Yes, you did, didn\'t you?" to Howard, Penny, Raj and Sheldon.\nPenny says "What the hell is that?" to Howard, Raj, Sheldon and Leonard.\nHoward says "Meatloaf." to Penny, Raj, Sheldon and Leonard.\nLeonard says "What was it doing on the ceiling?" to Howard, Penny, Raj and Sheldon.\nHoward says "That\'s classified." to Penny, Raj, Sheldon and Leonard.\nThe scene changes to: The International Space Station.\nVoice says "Houston, International Space Station. We have a little situation up here." to Houston and IISVoice.\nVoice says "We\'d like to make an unscheduled space walk." to Houston and IISVoice.\nHouston says "I.S.S., Houston. Which crew members would be involved in this E.V.A.?" to Voice and IISVoice.\nISS voice says "Houston, we\'d all like to step outside for a few minutes." to Voice, Houston and IISVoice.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Leonard’s car.\nSheldon says "What do you want to talk about?" to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Leonard’s car.\nThe scene changes to: Leonard’s bedroom. Morning.\nSheldon says "Well, I think I have a nice 2009 AnaMantle HC. It\'s usually indicated for acutely inflamed hemorrhoids, but it also goes nicely with non-mucosal body parts." to Priya and Leonard.\nLeonard says "Sounds great." to Priya and Sheldon.\nSheldon says "Excellent choice." to Priya and Leonard.\nLeonard says "(whispering): Okay, hurry, hurry, hurry. Come on, come on, come on." to Priya and Sheldon.\nSheldon says "SHELDON: Priya?" to Priya and Leonard.\nPriya says "Good morning, Sheldon." to Leonard and Sheldon.\nSheldon says "For shame, Leonard, for shame. And to think, I was ready to waste the last of my good hemorrhoid cream on you." to Priya and Leonard.\nThe scene changes to: Leonard’s car.\nLeonard says "Making pretty good time, huh?" to Sheldon.\nSheldon says "Is that really what you want to talk about, Leonard?" to Leonard.\nLeonard says "No." to Sheldon.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The apartment kitchen.\nLeonard says "This is brilliant, Sheldon. How are we going to deploy it in Kripke\'s office?" to Sheldon and Raj.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The apartment kitchen.\nThe scene changes to: The Cheesecake Factory. Howard enters.\nHoward says "Fair enough. When\'s your break?" to Bernadette.\nBernadette says "Wow." to Howard.\nHoward says "Don\'t you just hate it when this happens?" to Bernadette.\nPenny says "Wow." to to themselves.\nThe scene changes to: The apartment kitchen.\nSheldon says "All right, how\'s this for revenge? A solution of hydrogen peroxide, and one of saturated potassium iodide." to Raj and Leonard.\nRaj says "What\'s this?" to Sheldon and Leonard.\nSheldon says "Mountain Dew." to Raj and Leonard.\nSheldon says "Ahh, refreshing. Now, we\'re going to combine these chemicals with ordinary dish soap, creating a little exothermic release of oxygen." to Raj and Leonard.\nRaj says "Foamy vengeance." to Sheldon and Leonard.\nSheldon says "Yes, exactly." to Raj and Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The comic book store.\nLeonard says "but let me think about it and get back to you." to Sheldon, Howard, Raj and Stuart.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The comic book store.\nLeonard says "I guess the thing to do now is just pick yourself up, dust yourself off, forget it and move on." to Sheldon, Howard, Raj and Stuart.\nStuart says "- I can\'t do that. " to Sheldon, Leonard, Howard and Raj.\nStuart says "\'Cause we\'re going out again tomorrow." to Sheldon, Leonard, Howard and Raj.\nSheldon says "Excuse me, Stuart. Have you read the new Flash? Well, I have and it will knock your socks off!" to Leonard, Howard, Raj and Stuart.\nSheldon says "Good luck getting them back on." to Leonard, Howard, Raj and Stuart.\nStuart says "This is probably my last shot with Penny and I don\'t want to screw it up." to Sheldon, Leonard, Howard and Raj.\nLeonard says "Nobody wants that." to Sheldon, Howard, Raj and Stuart.\nStuart says "So, here\'s my question: It\'s the second date, you think she\'ll be expecting things to get physical?" to Sheldon, Leonard, Howard and Raj.\nLeonard says "Gee..." to Sheldon, Howard, Raj and Stuart.\nLeonard says "My initial reaction is no," to Sheldon, Howard, Raj and Stuart.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Leonard’s bedroom. Morning.\nPriya says "Oh! Leonard. Wake up." to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Leonard’s bedroom. Morning.\nThe scene changes to: The cafeteria.\nSheldon says "That\'s unacceptable. We\'re supposed to be given written notice." to Leonard.\nLeonard says "Well, no, it doesn\'t matter-- we\'ll be at work." to Sheldon.\nSheldon says "What if I spill tomato soup on my shirt, and have to come home to change, only to find there\'s no water for an enzyme soak?" to Leonard.\nLeonard says "Bifurcated uvula, Sheldon!" to Sheldon.\nSheldon says "I\'ll have the chicken noodle. Good night!" to Leonard.\nLeonard says "(whispering): We\'re going to have to be very quiet." to Sheldon and Priya.\nSheldon says "SHELDON: I know how to get the bucket! I can turn the axe around and use the handle to reach it. Let\'s see. (typing) Go north. You are in a forest. (typing) Go north. You are in a forest. (typing) Go north. You are in a forest. Oh dear, I believe I\'m lost. Well, I\'ll just have to get a fresh start tomorrow." to Leonard and Priya.\nLeonard says "No, no, no! You just took a wrong turn. You just need to map it out. Come on, I\'ll help you. So you stopped at the stream, and you turned north three times?" to Sheldon and Priya.\nSheldon says "Yes." to Leonard and Priya.\nLeonard says "You\'re right. You\'re lost. Good luck." to Sheldon and Priya.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The stairwell.\nSheldon says "I can\'t believe that." to Beverley.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The stairwell.\nThe scene changes to: Outside Penny’s door.\nLeonard says "I got a dressmaker\'s mannequin, I stuffed it with an electric blanket so it would be warm, and built two radio-controlled arms that would hug me and pat my back." to Penny.\nPenny says "That is so sad." to Leonard.\nLeonard says "You know what the saddest part was?  My father used to borrow it." to Penny.\nThe scene changes to: The stairwell.\nBeverley says "Your scan data will be very helpful to my research. You have a remarkable brain." to Sheldon.\nSheldon says "I know." to Beverley.\nSheldon says "Although I\'ve always hated how my right frontal lobe looks in pictures." to Beverley.\nBeverley says "Common complaint among men. Nothing\'s ever big enough." to Sheldon.\nBeverley says "Except when they get a tumor. Then you never hear the end of it." to Sheldon.\nSheldon says "I\'d love to see a scan of your brain sometime." to Beverley.\nBeverley says "I\'ll send you a link, but its physiology is fairly unimpressive." to Sheldon.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The university cafeteria. Leonard’s phone rings.\nSheldon says "- But the mission is for six months. " to Leonard, Raj and Howard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The university cafeteria. Leonard’s phone rings.\nSheldon says "Aren\'t you going to check your messages?" to Leonard.\nSheldon says "You have to check your messages! The living of a message is one half of a social contract which is completed by the checking of the message." to Leonard.\nSheldon says "If that contract breaks down, then all social contracts break down and we descend into anarchy." to Leonard.\nLeonard says "It must be hell inside your head." to Sheldon.\nSheldon says "At times." to Leonard.\nHoward says "Guys, we have a code red." to Leonard, Sheldon and Raj.\nSheldon says "Code Red the hospital emergency alert, the computer worm, or the cherry-flavored soft drink from the makers of Mountain Dew?" to Leonard, Raj and Howard.\nHoward says "Look, I was going over the schematics on my zero-G toilet, and I made a teeny tiny mistake on the specifications for the diverter valve." to Leonard, Sheldon and Raj.\nLeonard says "How teeny tiny?" to Sheldon, Raj and Howard.\nHoward says "It\'s gonna fail after about ten flushes." to Leonard, Sheldon and Raj.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: Penny’s apartment. There is a knock.\nPenny says "It\'s okay." to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Penny’s apartment. There is a knock.\nLeonard says "No. Lactose. Gas." to Penny.\nLeonard says "No. Sulfites. Migraines." to Penny.\nPenny says "Okay, well, I\'d offer you Halloween candy, but that\'s gone." to Leonard.\nPenny says "So, what\'s up?" to Leonard.\nLeonard says "Okay, we used to go out, right?" to Penny.\nPenny says "Oh, my God, that\'s where I know you from." to Leonard.\nLeonard says "I\'m dealing with a situation and it\'s kind of about my love life, so I know that might be weird for us to talk about, but in this area, as you know, all my other friends are just so stupid." to Penny.\nPenny says "All right, what\'s going on?" to Leonard.\nLeonard says "So, you\'re okay talking about this?" to Penny.\nPenny says "Yes. " to Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Alice’s apartment. Alice and Leonard are kissing\nLeonard says "Damn it, I can\'t. I can\'t do this." to Alice.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Alice’s apartment. Alice and Leonard are kissing\nThe scene changes to: Howard’s house. Sheldon rings the doorbell.\nSheldon says "Well, I thought he made that up. I-Isn\'t hypochondria a common idiosyncrasy of Jewish people?" to Howard and Bernadette.\nBernadette says "This is adrenaline-- we\'re gonna have to inject it into his heart." to Howard and Sheldon.\nSheldon says "We are?" to Howard and Bernadette.\nSheldon says "Oh, no! I can\'t!" to Howard and Bernadette.\nBernadette says "Hurry! We\'re running out of time!" to Howard and Sheldon.\nSheldon says "Okay." to Howard and Bernadette.\nSheldon says "Oh, God! One... two... three!" to Howard and Bernadette.\nHoward says "Trick or treat, bubbeleh." to Bernadette and Sheldon.\nSheldon says "What?" to Howard and Bernadette.\nSheldon says "No. You mean this was all a ruse? Oh, how could I be so stu..." to Howard and Bernadette.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The comic book store.\nLeonard says "- See you soon. " to Stuart.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The comic book store.\nLeonard says "During the kissing? What did you do, sneeze in her mouth? I did that to a girl once." to Stuart.\nStuart says "No, everything was good and really hot. And I said, Oh, Penny, and right where she was supposed to say, Oh, Stuart, she said... your name." to Leonard.\nStuart says "That is your name, right?" to Leonard.\nLeonard says "I\'m sorry. That must\'ve been the last thing you wanted to hear." to Stuart.\nStuart says "It beats, You know I\'m a dude, right?" to Leonard.\nStuart says "Yeah, it was pretty bad." to Leonard.\nLeonard says "No doubt, no doubt." to Stuart.\nLeonard says "I\'m sorry it didn\'t work out." to Stuart.\nStuart says "Not your fault." to Leonard.\nLeonard says "Yeah, how about that?" to Stuart.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The apartment.\nMartha says "Uh-huh." to Sheldon and Raj.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The apartment.\nThe scene changes to: The laundry room.\nPenny says "You know, I believe in ghosts, too." to Leonard.\nLeonard says "Great. " to Penny.\nLeonard says "I know, and pyramid power and healing crystals." to Penny.\nPenny says "Oh, no, no, no, crystals don\'t work." to Leonard.\nLeonard says "Really, that\'s the line? Psychics are real, but crystals are voodoo?" to Penny.\nPenny says "Oh, voodoo\'s real. You don\'t want to mess with voodoo." to Leonard.\nThe scene changes to: The apartment.\nMartha says "Flatland is more than just a mathematical essay. It is also a treatise on Victorian social mores." to Sheldon and Raj.\nSheldon says "You know, I had never considered that." to Martha and Raj.\nSheldon says "Wow, that\'s going to completely change my visits there." to Martha and Raj.\nSheldon says "Well, it\'s late." to Martha and Raj.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The cinema.\nHoward says "I\'m sorry. Don\'t you have a spare?" to Raj and Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The cinema.\nThe scene changes to: The stairwell.\nPenny says "What does that mean?" to Sheldon.\nSheldon says "Based on what happened next, I assume it means, Would you like an enema?" to Penny.\nPenny says "Okay, sweetie. I\'ll take care of you. What do you need?" to Sheldon.\nSheldon says "My Mom used to give me sponge baths." to Penny.\nPenny says "Okay, ground rules: no sponge baths, and definitely no enemas." to Sheldon.\nSheldon says "Agreed." to Penny.\nThe scene changes to: The cinema.\nRaj says "Here we go. Ten-and-a-half hours of ape-y goodness." to Leonard and Howard.\nLeonard says "Damn it, my glasses. Okay, I\'m blind here, guys. Can you help me find them?" to Raj and Howard.\nHoward says "Sorry. Found them." to Raj and Leonard.\nLeonard says "Oh, great." to Raj and Howard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Howard’s bathroom. He is in the bath.\nKatee says "Sure. But can I ask you a question first?" to Howard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Howard’s bathroom. He is in the bath.\nThe scene changes to: Kripke is in a storage cupboard of some kind. He has tubes rigged up through the roof attached to helium tanks which he is turning on. The radio is playing. \nSheldon says "A north and south pole. If you cut that in half, you have two smaller magnets, each with its own north and south pole." to Ira.\nIra says "Uh, Dr. Cooper, I think there might be something wrong with our connection." to Sheldon.\nSheldon says "No, I hear you fine." to Ira.\nSheldon says "As I was saying, an ordinary magnet has two poles. The primary characteristic of a monopole is that it has only one pole, hence, monopole." to Ira.\nSheldon says "A requirement for string theory, or M-theory, if you will, is the existence of such monopoles. I, myself, led an expedition to the Arctic Circle in search of said particles. Kripke, I found the nozzle! I\'m going to kill you!" to Raj, Howard, Leonard, Kripke and sheldon.\nThe scene changes to: Howard’s bathroom. He is in the bath.\nHoward says "So nice you could join me this evening. You\'re looking lovely as always." to Katee.\nKatee  says "Thanks, Howard. Always nice to be part of your masturbatory fantasies." to Howard and Katee.\nHoward says "Come on, Katee. Don\'t make it sound so cheap." to Katee.\nKatee says "I\'m sorry, fiddling with yourself in the bathtub is a real class act." to Howard.\nHoward says "Thank you. So, shall we get started?" to Katee.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Leonard’s lab.\nHoward says "Hey." to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Leonard’s lab.\nThe scene changes to: A restaurant.\nLeonard says "Maybe we should just stop talking about this." to Bernadette, Penny and Howard.\nPenny says "Maybe some of us should stop talking altogether." to Bernadette, Leonard and Howard.\nWaiter says "How is everything tonight?" to Bernadette, Leonard, Penny and Howard.\nBernadette says "Really uncomfortable." to Leonard, Penny and Howard.\nThe scene changes to: The stairwell.\nLeonard says "You know, the best thing about being in a committed, monogamous, mutually supportive relationship is that even if you have different ideas, you can have a spirited debate, yet still care for, even make love with..." to Penny.\nLeonard says "Want your fish?" to Penny.\nLeonard says "I knew you were going to do that. Doesn\'t make me psychic!" to Penny.\nLeonard says "Attaboy, Leonard, make it worse." to Penny.\nThe scene changes to: Leonard’s lab.\nLeonard says "What\'s going on?" to Sheldon and Raj.\nSheldon says "We scored. I\'m the wingman." to Leonard and Raj.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The university mixer.\nSheldon says "I would like a root beer float." to Raj.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The university mixer.\nThe scene changes to: Leonard’s car.\nPenny says "Bite me." to Leonard, Howard and Bernadette.\nLeonard says "Come on, Penny." to Howard, Penny and Bernadette.\nHoward says "Why don\'t you kids go ahead and chat? We\'re gonna make out back here." to Leonard, Penny and Bernadette.\nBernadette says "I\'m sliding into third." to Leonard, Howard and Penny.\nThe scene changes to: The university mixer.\nRaj says "Thanks for coming with me." to Sheldon.\nSheldon says "Thanks for giving me your limited edition Green Lantern lantern." to Raj.\nRaj says "Did you really have to bring it in with you?" to Sheldon.\nSheldon says "What if evil strikes and my power ring runs low?" to Raj.\nRaj says "Come on, let\'s get a drink. " to Sheldon.\nRaj says "Yeah, well I do. And when my wingman is carrying a Green Lantern lantern, I drink a lot. I\'ll have a screwdriver, please. Don\'t be chintzy with the screw." to Sheldon.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The apartment.\nPenny says "What exactly does that mean?" to Howard and Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The apartment.\nThe scene changes to: Outside an apartment building.\nHoward says "It\'s not like "chicken or fish" on an airplane?" to Bernadette.\nBernadette says "Maybe you need to think about it a little." to Howard.\nHoward says "You know, it\'s not unheard of for a one-night stand to turn into a relationship." to Bernadette.\nBernadette says "Call me when you figure it out." to Howard.\nHoward says "Three dates means sex?" to Bernadette.\nHoward says "Who knew?" to Bernadette.\nThe scene changes to: The apartment.\nHoward says "Greetings, homies." to Penny and Leonard.\nHoward says "Homette." to Penny and Leonard.\nPenny says "Why are you back from your date so early?" to Howard and Leonard.\nHoward says "In romance, as in show business, always leave them wanting more." to Penny and Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The laundry room.\nLeonard says "Great. " to Penny.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The laundry room.\nLeonard says "No, I\'m sorry. I really am. It\'s not right to mock what a person believes in." to Penny.\nPenny says "Thank you. Would you be willing to go to my psychic and see what it\'s all about?" to Leonard.\nLeonard says "Would you be willing to read a book that concisely explains how all psychics are frauds?" to Penny.\nPenny says "I would not." to Leonard.\nLeonard says "Okay, let\'s go see your psychic." to Penny.\nPenny says "Really?" to Leonard.\nLeonard says "Well, yeah, one of us has to keep an open mind." to Penny.\nPenny says "You saying I don\'t have an open mind?" to Leonard.\nLeonard says "No, n-not at all. Let me help you with this stuff." to Penny.\nPenny says "You know, I believe in ghosts, too." to Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The lobby. Penny finds a woman studying the lift.\nPenny says "Nice to meet you." to Leonard’sMother.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The lobby. Penny finds a woman studying the lift.\nHoward says "How about that, you were right." to Sheldon, Raj, Penny and Leonard.\n----- says "Laughing " to Penny and Woman.\nPenny says "It\'s out of order." to Woman.\nWoman says "Yes, I can read the sign. I\'m just pondering the implications." to Penny.\nPenny says "I think it implies that the elevator doesn\'t work." to Woman.\nWoman says "Again, I can read the sign. But the sign and the tape are covered with a layer of dust, which indicates that the elevator has been nonfunctional for a significant amount of time. Which suggests either a remarkable passivity among the, I assume, 24 to 36 residents of this building, based on the number of mailboxes and given typical urban population density or a shared delusion of functionality." to Penny.\nPenny says "You must be Leonard\'s mother." to Woman.\nLeonard’s Mother says "I don\'t know if I must be, but yes." to Penny and Leonard’sMother.\nPenny says "I\'m Penny. I\'m his neighbor." to Leonard’sMother.\nLeonard’s Mother says "Dr. Beverly Hofstadter." to Penny and Leonard’sMother.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The apartment. Leonard is with Alice.\nAlice says "Yeah. It\'s kinda based on my life." to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The apartment. Leonard is with Alice.\nThe scene changes to: Entering the apartment building.\nPenny says "What\'s with him? " to Sheldon and Leonard.\nLeonard says "You might be from Texas, but I\'m from New Jersey." to Sheldon and Penny.\nThe scene changes to: The apartment. Leonard is with Alice.\nLeonard says "Check it out. Jim Lee drew this of me two years ago at Comic Con." to Alice.\nAlice says "What are you wearing?" to Leonard.\nLeonard says "Well, you know, it\'s Comic Con." to Alice.\nLeonard says "I\'m Lion-O from ThunderCats." to Alice.\nAlice says "Wow, you must have gotten so laid." to Leonard.\nLeonard says "No. But Jessica Alba did rub my furry belly." to Alice.\nAlice says "Want to see a comic I draw?" to Leonard.\nLeonard says "You\'re kidding. You have your own book?" to Alice.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The university mixer.\nAbby says "Hi, Raj. Where are you from?" to Raj and Sheldon.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The university mixer.\nRaj says "Thanks." to Sheldon.\nSheldon says "Thank you. And what is my function as "wingman?"" to Raj.\nRaj says "You help me run my game." to Sheldon.\nSheldon says "Okay. What is your game?" to Raj.\nSheldon says "When I lie through my teeth to a woman, you nod and agree." to Raj.\nGirl says "Hey, that\'s pretty cool. What is it?" to Raj and Sheldon.\nSheldon says "It\'s a limited edition Green Lantern lantern. My friend is looking for someone to copulate with." to Raj.\nGirl says "You\'re very funny. I\'m Abby." to Raj and Sheldon.\nSheldon says "I\'m Sheldon. How do you do?" to Raj and Girl.\nRaj says "Rajesh Ramayan Koothrappali. Call me Raj. " to Sheldon and Girl.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The Cheesecake Factory. Howard enters.\nBernadette says "I can\'t now, I\'m working." to Howard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The Cheesecake Factory. Howard enters.\nThe scene changes to: Sheldon’s bedroom. \nSheldon says "Oh! How about we put a whoopee cushion on his office chair?" to Leonard and Raj.\nSheldon says "He\'ll sit down, it\'ll sound like he\'s flatulent, even though he\'s not." to Leonard and Raj.\nLeonard says "Let\'s keep thinking." to Sheldon and Raj.\nThe scene changes to: The Cheesecake Factory. Howard enters.\nPenny says "Oh, gee, you\'re too late. Scarlett Johansson and Wonder Woman were just in here trolling around for neurotic, little weasels." to Howard.\nHoward says "I came to talk to Bernadette. She\'s working today, right?" to Penny.\nPenny says "Yes, but I don\'t think she wants to see you." to Howard.\nHoward says "Why not?" to Penny.\nPenny says "Come on, Howard. You hurt her feelings by not calling her all week. Plus, I\'ve kind of been talkin\' some smack about ya." to Howard.\nBernadette says "Hello, Howard." to Howard.\nHoward says "Wait, Bernadette, I need to talk to you." to Bernadette.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The apartment.\nPenny says "Here\'s your soup." to Sheldon.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The apartment.\nThe scene changes to: Penny’s bedroom.\nLeonard says "What\'s going on?" to Penny.\nPenny says "I\'m having a tea party. What do you think\'s going on?" to Leonard.\nPenny says "I think I might have the flu." to Leonard.\nPenny says "Or the plague." to Leonard.\nLeonard says "Well, our plane leaves at 9:00 a.m. Do you think you\'ll feel better by then?" to Penny.\nPenny says "Yep. \'Cause I\'m gonna be dead." to Leonard.\nThe scene changes to: Outside Sheldon’s bedroom.\nLeonard says "Hey, Sheldon? Listen, Penny is pretty sick and she\'s not going to be able to go to Switzerland. So if you\'re still interested, you\'re welcome to come." to Sheldon.\nSheldon says "Great. I\'ll start packing." to Leonard.\nSheldon says "In a minute." to Leonard.\nSheldon says "Oh, look, it\'s the cholermus." to Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Leonard’s bedroom. Morning.\nPriya says "Where are you going with this, Leonard?" to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Leonard’s bedroom. Morning.\nThe scene changes to: The cafeteria.\nSheldon says "Yes." to Leonard and Priya.\nLeonard says "You\'re right. You\'re lost. Good luck." to Sheldon and Priya.\nThe scene changes to: Leonard’s bedroom. Morning.\nPriya says "Oh! Leonard. Wake up." to Leonard.\nLeonard says "Huh? Wh-- Sorry." to Priya.\nPriya says "For what?" to Leonard.\nLeonard says "I don\'t know. When I\'m in bed with a girl, it\'s just-- it\'s my go-to response." to Priya.\nPriya says "It\'s 6:00. I have to get back to Raj\'s before he wakes up and realizes I\'m gone." to Leonard.\nLeonard says "Oh. Right. Sure. I wish you could stay in L.A. a while longer." to Priya.\nPriya says "Mmm, me, too." to Leonard.\nLeonard says "You know, I was thinking: There are some great research facilities in India." to Priya.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The lobby.\nPenny says "In that case, do you mind giving me some advice?" to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The lobby.\nPenny says "You know your friend Stuart?" to Leonard.\nPenny says "He asked me out again and I said yes, and then I started thinking maybe I should talk to you first." to Leonard.\nLeonard says "About what?" to Penny.\nPenny says "Does it bother you, me going out with one of your friends? \'Cause you know, you and me..." to Leonard.\nLeonard says "No, that\'s the past." to Penny.\nLeonard says "I\'m really more of a right now kind of guy. You know, living in the moment. Although I do have to live a little in the future, \'cause that\'s my job." to Penny.\nLeonard says "Of course, my fondness for classic science fiction does draw my attention backwards, but those stories often take place in the future." to Penny.\nLeonard says "In conclusion, no, it doesn\'t bother me." to Penny.\nPenny says "Okay, well, that\'s really cool of you." to Leonard.\nLeonard says "I wouldn\'t say cool. I\'d just say... That\'s Leonard!" to Penny.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The university mixer.\nRaj says "Thanks for coming with me." to Sheldon.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The university mixer.\nThe scene changes to: Leonard’s car.\nLeonard says "Wh... Seriously? You\'re getting career advice from a psychic?" to Howard, Penny and Bernadette.\nHoward says "Good job not making fun of her." to Leonard, Penny and Bernadette.\nPenny says "She\'s not one of those phonies, okay. She wrote a book and has her own Web site." to Leonard, Howard and Bernadette.\nLeonard says "Oh, gee, why didn\'t you say so? They don\'t let just anyone have a Web site." to Howard, Penny and Bernadette.\nPenny says "Why are you being such a jerk?" to Leonard, Howard and Bernadette.\nLeonard says "You\'re surprised? Your psychic tell you I was going to be a jerk?" to Howard, Penny and Bernadette.\nPenny says "Bite me." to Leonard, Howard and Bernadette.\nLeonard says "Come on, Penny." to Howard, Penny and Bernadette.\nHoward says "Why don\'t you kids go ahead and chat? We\'re gonna make out back here." to Leonard, Penny and Bernadette.\nBernadette says "I\'m sliding into third." to Leonard, Howard and Penny.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
# ...
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The comic book store.\nLeonard says "Hey, Stuart, I need to talk to you." to Stuart.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The comic book store.\nThe scene changes to: The apartment.\nLeonard says "- Thanks for understanding, Howard. " to sheldon, Howard and Raj.\nHoward says "All right, I think we\'ve got a prototype ready to test. Hand me that Tupperware." to Sheldon and Raj.\nRaj says "That\'s heavy." to Sheldon and Howard.\nHoward says "Damn right it\'s heavy. It\'s my mother\'s meat loaf." to Sheldon and Raj.\nHoward says "It\'s been testing toilets for generations." to Sheldon and Raj.\nSheldon says "I must say, I think a detailed letter to MIT describing your current circumstances might entitle you to a refund on your master\'s degree." to Howard and Raj.\nHoward says "Okay, simulated zero-gravity human waste disposal test with meat loaf analog in... three, two, one." to Sheldon and Raj.\nSheldon says "Fascinating." to Howard and Raj.\nRaj says "What do you think the problem is?" to Sheldon and Howard.\nHoward says "Not enough bread crumbs." to Sheldon and Raj.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The stairwell.\nSheldon says "Wait! Where are you going?" to Penny.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The stairwell.\nThe scene changes to: The cinema. Everyone is wearing ape masks.\nPenny says "Can you please come get him?" to Howard, Raj, Leonard and Sheldon.\nLeonard says "Yeah, I\'d be happy to." to Howard, Raj, Penny and Sheldon.\nLeonard says "Oh, my God, there\'s a breach in the radiation unit! The whole city is in jeopardy! Oh, my God! The containment vessel\'s melting. Gotta go. Bye!" to Howard, Raj, Penny and Sheldon.\nLeonard says "I feel really guilty." to Howard and Raj.\nRaj says "You did what you had to do." to Howard and Leonard.\nHoward says "Take your stinking paws off my popcorn, you damn dirty ape!" to Raj and Leonard.\nThe scene changes to: The stairwell.\nSheldon says "Thanks for bringing me home." to Penny.\nPenny says "It\'s okay. I didn\'t really need to work today. It\'s not like I have rent or car payments or anything." to Sheldon.\nSheldon says "Good, good." to Penny.\nPenny says "Okay, well, you feel better." to Sheldon.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: Sheldon’s bedroom. Sheldon wakes up and coughs. Picks up an electronic thermometer and takes his temperature.\nLeonard says "All right, get some rest and drink plenty of fluids." to Sheldon.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Sheldon’s bedroom. Sheldon wakes up and coughs. Picks up an electronic thermometer and takes his temperature.\nSheldon says "Leonard, where are you?" to Leonard.\nLeonard  says "I\'m at work." to Sheldon and Leonard.\nSheldon says "At 6:30 in the morning?" to Leonard.\nSheldon says "On Sunday?" to Leonard.\nSheldon says "Why?" to Leonard.\nSheldon says "I didn\'t hear the phone ring." to Leonard.\nLeonard says "They texted me." to Sheldon.\nSheldon says "Well, as I predicted, I am sick. My fever has been tracking up exponentially since 2:00 a.m., and I am producing sputum at an alarming rate." to Leonard.\nLeonard says "No kidding?" to Sheldon.\nSheldon says "No, not only that, it has shifted from clear to milky green." to Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The apartment. Howard is on the phone.\nHoward says "Well, they\'ve deployed our solution. Let\'s just all hope it works." to Penny, Raj, Sheldon and Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The apartment. Howard is on the phone.\nThe scene changes to: The comic book store.\nStuart says "It beats, You know I\'m a dude, right?" to Leonard.\nStuart says "Yeah, it was pretty bad." to Leonard.\nLeonard says "No doubt, no doubt." to Stuart.\nLeonard says "I\'m sorry it didn\'t work out." to Stuart.\nStuart says "Not your fault." to Leonard.\nLeonard says "Yeah, how about that?" to Stuart.\nLeonard says "- See you soon. " to Stuart.\nThe scene changes to: The apartment. Howard is on the phone.\nHoward says "Yes, sir, I understand classified. We\'ll keep it all classified; no one has to know but you and me." to Penny, Raj, Sheldon and Leonard.\nPenny says "What\'s classified?" to Howard, Raj, Sheldon and Leonard.\nLeonard says "Howard\'s space toilet. I\'ll tell you later." to Howard, Penny, Raj and Sheldon.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Bernadette’s car.\nBernadette says "I don\'t know. My dad\'s pretty insistent on it, though." to Howard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Bernadette’s car.\nThe scene changes to: Amy’s laboratory.\nAmy says "No." to Sheldon.\nSheldon says "...that the soap was..." to Amy.\nAmy says "Sheldon." to Sheldon.\nSheldon says "Fine. Sorry." to Amy.\nAmy says "You\'re forgiven. Now, if you want to stay, get started on those beakers. They\'re still dirty from yesterday." to Sheldon.\nSheldon says "Next year I\'m going to Epcot." to Amy.\nThe scene changes to: Bernadette’s car.\nBernadette says "Are you mad at me?" to Howard.\nHoward says "No. I\'m not mad at you. I just... wish you would have come to me, so I didn\'t have to hear it through the nerd-vine." to Bernadette.\nBernadette says "So, what are we gonna do?" to Howard.\nHoward says "You really want me to sign a prenup?" to Bernadette.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: The lobby. Penny finds a woman studying the lift.\nPenny says "I had a wonderful childhood." to Beverley.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The lobby. Penny finds a woman studying the lift.\nPenny says "Five." to Beverley.\nBeverley says "At that age, he was well enmeshed in what Freud would call the phallic stage of psychosexual development. An outmoded theory, of course, but the boy did spend most of his waking hours with a tight grasp on his penis." to Penny.\nPenny says "Leonard mentioned you were a psychiatrist." to Beverley.\nBeverley says "That is one of my degrees. My primary field is neuroscience." to Penny.\nPenny says "Well, I\'m an actress." to Beverley.\nBeverley says "Why?" to Penny.\nPenny says "What do you mean why?" to Beverley.\nBeverley says "There are studies that suggest that many who go into the performing arts suffer from an external locus of identity." to Penny.\nPenny says "Yeah, I don\'t know what that means." to Beverley.\nBeverley says "It means you value yourself only as others value you, which is often the result of unmet childhood emotional needs." to Penny.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: Penny’s bedroom.\nPenny says "Oh!" to Leonard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Penny’s bedroom.\nThe scene changes to: The apartment.\nSheldon says "Well then, you leave me no alternative. From this moment forward, we can be roommates, but we will no longer be friends." to Raj, Howard and Leonard.\nLeonard says "I\'m sorry you feel that way." to Raj, Howard and Sheldon.\nSheldon says "I don\'t think you\'re fully aware of the ramifications here, Leonard. (sighs)" to Raj, Howard and Leonard.\nLeonard says "Why don\'t you enlighten me?" to Raj, Howard and Sheldon.\nSheldon says "With the friendship clause of our roommate agreement nullified you are no longer entitled to accompany me to go swimming at Bill Gates\' house should I be invited." to Raj, Howard and Leonard.\nHoward says "Ooh, that\'s gotta sting." to Raj, Leonard and Sheldon.\nThe scene changes to: Penny’s bedroom.\nLeonard says "Just think, this time tomorrow we\'ll be in Geneva, Switzerland for our first Valentine\'s Day." to Penny.\nPenny says "I know! I went shopping today and bought special undies for the occasion." to Leonard.\nLeonard says "Thermal? \'Cause it\'s gonna be cold." to Penny.\nPenny says "Think it through, Leonard." to Leonard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe scene changes to: The cafeteria.\nRaj says "Hey, so what did you guys think of the new episode of Caprica last night?" to Sheldon, Leonard and Howard.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: The cafeteria.\nThe scene changes to: Leonard’s lab.\nSheldon says "From an orangutan in the primate lab." to Leonard.\nLeonard says "An orangutan?" to Sheldon.\nSheldon says "Well, no one\'s going to run a DNA test on it, Leonard. Honestly, you overthink everything." to Leonard.\nLeonard says "Sheldon, I don\'t need an alibi. Nobody\'s going to ask about last night as long as you just zip your lip. Thank you. Now, don\'t worry, everything is going to be fine." to Sheldon.\nThe scene changes to: The cafeteria.\nLeonard says "Hey." to Sheldon, Raj and Howard.\nRaj says "Hey, Leonard, will you please tell Howard my sister has never been attracted to him?" to Sheldon, Leonard and Howard.\nLeonard says "Come on, Raj, how am I supposed to know who she is attracted to or was attracted to or who she might be attracted to in the future?" to Sheldon, Raj and Howard.\nSheldon says "And I have nothing to contribute to this conversation." to Leonard, Raj and Howard.\nSheldon says "Because I, too, know absolutely nothing about Priya\'s preferences in male companionship." to Leonard, Raj and Howard.\nSheldon says "And with that, I will re-zip my lip." to Leonard, Raj and Howard.\n'}],
#   'output': '0'},
#  {'input': [{'role': 'system',
#     'content': "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."},
#    {'role': 'user',
#     'content': 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond \'1\' for humorous or \'0\' for not humorous:\n\nThe Scene is still: Howard’s house. Sheldon rings the doorbell.\nBernadette says "Hurry! We\'re running out of time!" to Howard and Sheldon.'},
#    {'role': 'assistant',
#     'content': 'Can you provide some context to help me with this decision?'},
#    {'role': 'user',
#     'content': 'Yes, use the following as context:\n\nThe Scene is still: Howard’s house. Sheldon rings the doorbell.\nSheldon says "Holy smoke, why didn\'t I think of that? You\'re a better man than I, Howard Wolowitz. You put \'er there, you son of a gun!" to Howard and Bernadette.\nHoward says "Whatever. " to Bernadette and Sheldon.\nHoward says "My... oh... it\'s..." to Bernadette and Sheldon.\nBernadette says "Oh, my God, Howard! What did you do?" to Howard and Sheldon.\nSheldon says "It was a harmless Halloween prank. Look." to Howard and Bernadette.\nBernadette says "Howard has a heart condition! You know that!" to Howard and Sheldon.\nSheldon says "Well, I thought he made that up. I-Isn\'t hypochondria a common idiosyncrasy of Jewish people?" to Howard and Bernadette.\nBernadette says "This is adrenaline-- we\'re gonna have to inject it into his heart." to Howard and Sheldon.\nSheldon says "We are?" to Howard and Bernadette.\nSheldon says "Oh, no! I can\'t!" to Howard and Bernadette.\n'}],
#   'output': '0'}]

# %% [markdown]
# # Some interesting outputs along the way:
#
# ## user: "**What do you know about the sitcom the Big Bang Theory?**"
#
# A popular and iconic sitcom! The Big Bang Theory is a American sitcom that originally aired from 2007 to 2019. Created by Chuck Lorre and Bill Prady, the show is a comedy about a group of socially awkward and intellectually brilliant scientists and their neighbor, a waitress and aspiring actress.
#
# The show revolves around the lives of five main characters:
#
# 1. Sheldon Cooper (played by Jim Parsons), a theoretical physicist with Asperger's syndrome and a strict adherence to routine.
# 2. Leonard Hofstadter (played by Johnny Galecki), an experimental physicist and Sheldon's roommate and best friend.
# 3. Howard Wolowitz (played by Simon Helberg), an aerospace engineer and fellow physicist who lives across the hall from Leonard and Sheldon.
# 4. Rajesh "Raj" Koothrappali (played by Kunal Nayyar), an astrophysicist who is unable to speak in the presence of women unless he drinks alcohol.
# 5. Penny (played by Kaley Cuoco), a waitress and aspiring actress who lives across the hall from Leonard and Sheldon.
#
# Throughout the show's 12 seasons, the characters navigate their personal and professional lives, often finding themselves in humorous and absurd situations. The show explores themes such as friendship, love, and the [cut off]
#
# -------------------
#
# ## Prompt:
# system: "You are humor classification model that takes a given line (the target) along with several precending lines (the context), and determines whether the target line was humorous (return '1') or not humorous (return '0'). RESTRICTION: ONLY RESPOND 1 OR 0."
#
# user: 'Is the following target_moment from the sitcom, the Big Bang Theory, humorous or not humorous? Only respond '1' for humorous or '0' for not humorous:
#
# The Scene is still: The Cafeteria
# Sheldon says "It's not what it looks like." to Leonard.'
#
# assistant: 'Can you provide some context to help me with this decision?'
#
# user: 'Yes, use the following as context:
#
# The Scene is still: The Cafeteria
# Priya says "My brother-- he's got a big crush on Bernadette." to Leonard.
# Leonard says "You're moving back to India?" to Priya.
# Leonard says "What's going on?" to Raj, Penny, Raj and Howard.
# Penny says "It's-It's not what it looks like." to Raj, Leonard, Raj and Howard.Sheldon says "What does it look like?" to Raj, Leonard, Raj and Howard.
#
#
# ## Model's Response:
#
# Based on the context, I would classify the target moment as humorous. The phrase "It's not what it looks like" is a common idiomatic expression, but in this scene, it's being used in a way that's reminiscent of a soap opera or a melodrama, which adds a layer of humor to the situation. The fact that Sheldon is asking "What does it look like?" also implies that he's being obtuse and unaware of the obvious, which is a characteristic that's often played for comedic effect in the show.
