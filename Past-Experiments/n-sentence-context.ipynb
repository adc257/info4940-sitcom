# %% [markdown]
# # The Big Bang Theory Exploratory Data Analysis

# %% [markdown]
# ### Imports:

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta, time
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Loading sample data file:

# %%
with open("cleaned-data/S1/The Big Bang_S0101.json", 'r') as file:
    s1e1Data = json.load(file)

# %%
s1e1Data
# Out:
# {'00:00:00:140000': {'EpisodeID': 'The Big Bang_S0101',
#   'Scene': 'A corridor at a sperm bank.',
#   'Recipients': ['Leonard'],
#   'Speaker': 'Sheldon',
#   'Dialogue': "So if a photon is directed through a plane with two slits in it and either slit is observed, it will not go through both slits. If it's unobserved, it will. However, if it's observed after it's left the plane but before it hits its target, it won't have gone through both slits.",
#   'Dialogue Start Time': '00:00:00:140000',
#   'Dialogue End Time': '00:00:12:140000'},
#  '00:00:12:180000': {'EpisodeID': 'The Big Bang_S0101',
#   'Scene': 'A corridor at a sperm bank.',
#   'Recipients': ['Sheldon'],
#   'Speaker': 'Leonard',
#   'Dialogue': "Agreed. What's your point?",
#   'Dialogue Start Time': '00:00:12:180000',
#   'Dialogue End Time': '00:00:14:180000'},
#  '00:00:14:230000': {'EpisodeID': 'The Big Bang_S0101',
#   'Scene': 'A corridor at a sperm bank.',
#   'Recipients': ['Leonard'],
# ...

# %%
s1e1_df = pd.DataFrame.from_dict(s1e1Data, orient='index')
s1e1_df
# Out:
#                           EpisodeID                        Scene  \
# 00:00:00:140000  The Big Bang_S0101  A corridor at a sperm bank.
# 00:00:12:180000  The Big Bang_S0101  A corridor at a sperm bank.
# 00:00:14:230000  The Big Bang_S0101  A corridor at a sperm bank.
# 00:00:23:140000  The Big Bang_S0101  A corridor at a sperm bank.
# 00:00:29:150000  The Big Bang_S0101  A corridor at a sperm bank.
# ...                             ...                          ...
# 00:21:43:090000  The Big Bang_S0101   All five in Leonard’s car.
# 00:21:49:180000  The Big Bang_S0101   All five in Leonard’s car.
# 00:21:53:110000  The Big Bang_S0101   All five in Leonard’s car.
# 00:21:58:140000  The Big Bang_S0101   All five in Leonard’s car.
# 00:22:13:060000  The Big Bang_S0101   All five in Leonard’s car.
#
#                                       Recipients  Speaker  \
# 00:00:00:140000                        [Leonard]  Sheldon
# 00:00:12:180000                        [Sheldon]  Leonard
# ...
